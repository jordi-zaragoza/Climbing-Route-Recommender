# %%
from difflib import SequenceMatcher
import pandas as pd 
import numpy as np
from lib.location_class import location
import regex as re
import unicodedata
from lib.text_processor_class import *

# %% [markdown]
# # Text processor

# %% [markdown]
# I need to create a text processor in order to:
# - Clean strings, Remove all not alphanumeric values
# - Check how similar are all words of a list and replace most frequent
# - Check the language of the comments
# - Check if a comment is possitive or negative based on the language
#
# I will include all this functions inside a class called text_processor

# %% [markdown]
# #### Retrieve the data

# %%
ascent_df = pd.read_csv('../../databases/ascent_grade_correction.csv', low_memory=False)
lc = location(ascent_df)
# Out:
# Location class initialized

# %%
crags = lc.crags_in_country('SWE')
myset1 = set(crags)
myset1
# Out:
# {nan,
#  'BjörnParken',
#  'Nedre Koppom',
#  'slättmon',
#  'Haninge',
#  'Stapelbäddsparken / Gråa blocket',
#  'Grytorna',
#  'Söcke',
#  'Ramberget',
#  'Rosenbo',
#  'Introväggarna',
#  'Marnäs / Lungsjöån',
#  'Majoreberget',
#  'bladmyran/Gävle',
#  'Aspe',
#  'Bjässberget',
#  'Mörrösjöliastenen',
#  'Norrköping',
#  'Vkers',
#  'vo västervik',
#  'vardkaseberget',
#  'almenäs',
#  'Bônn',
#  'Fullbroberget',
#  'Töcksfors',
#  'Söderbylund',
#  'Lännaby Blocket',
#  'Evenröd',
#  'Lillsjö',
#  'Hälsö',
#  'karatetaket',
#  'S2',
#  'Älvenäs',
#  'Sibracka',
#  'järna-kullen',
#  'Tumba klippan',
#  'Ryssbergen',
#  'Gimmen/Gagnef',
#  'Romsen',
#  'Playground',
#  'Töllsjöö',
#  'Jungfruberget',
#  'Enskällaboberg',
#  'Hemligt ett tag till',
#  'Hagaparken',
#  'Krondiket',
#  'Born/Ljugarn',
#  'Stikkväg 4',
#  'Övre sjöstenen/VO',
#  'Brodal',
#  'Kalvsvik',
#  'Grottbeget',
#  'olberget',
#  'Björsäter',
#  'Läckö slott',
#  'Uggleberget',
#  'Sjöstenen/Vo',
#  'Frøsøberget',
#  'Fruberget/ Sthlm',
#  'tibbhult',
#  'Valsan',
#  'hågelbyleden',
#  'Oskarsström',
#  'Degersjöberget',
#  'Mörby',
#  'Sollefteå',
#  'Stuguberget',
#  'Fornborgen',
#  'Ågelsjön',
#  'Lillknipen',
#  'Gunnilse',
#  'Ljusne',
#  'Hemlig ny',
#  'hestra stenen',
#  'marna',
#  'Närboberget',
#  'Odensberg',
#  'Fruberget',
#  'häller',
#  'Gustafsbergs vattentorn',
#  'adfad',
#  'Vägg1',
#  'Önsta',
#  'tjuvklyftan',
#  'steneby grottan',
#  'Gritstoneberget',
#  'Fjärås - Skärsjön',
#  'tavelsjöberget',
#  'Fjällbacka öst',
#  'Göteborg',
#  'salem',
#  'Borgväggen, Sollentuna',
#  'Gubbo',
#  'Örneström',
#  'Vedema Hall',
#  'Lyrön',
#  'Fabben',
#  'rösås',
#  'Hygget, Östergötland',
#  'Ramnäs/66',
#  'F-6',
#  'Flygande Korven',
#  'Kungsladugård',
#  'Bergviksberget',
#  'Viss gärde',
#  'Bohuslän',
#  'Toltorp',
#  'Tolarpsskogen',
#  'Brotorp',
#  'Block 1',
#  'Svarttjärn/ö-vik',
#  'Kilen',
#  'Lobjörnberget',
#  'Övre östra hylteberget',
#  'Miniträsket',
#  'Lägerbålsblocket',
#  'Karstens Ränna',
#  'Tunbyn',
#  'sibracka',
#  'Ikea Blocken',
#  'Höjden',
#  'Bonkers',
#  'Hestrastenen/Borås',
#  'awdaw',
#  'Sjötorpsverget',
#  'Huesa',
#  'Smålinden',
#  'dalarna',
#  'Ängårdsbergen',
#  'Broma',
#  'Tranås Boulder',
#  'Bjornblocket',
#  'Hagbyberget',
#  'k2',
#  'SP',
#  'segersäng',
#  'Görvälstorp',
#  'Svampskogen',
#  'Kolartorp',
#  'Secret spot',
#  'Xx trackside',
#  'Hygget,Östergötland',
#  'Stickväg 5',
#  'Änga/Sveden',
#  'Stora blocket',
#  'Karshultvägen',
#  'Lysingsbadet',
#  'Gaseborg',
#  'flurkmark',
#  'Morarna gålö',
#  'Rås väggen',
#  'Hammarbacken',
#  'någonstans på den skånska slätten',
#  'träleberget',
#  'krossberget',
#  'Heby',
#  'Vägstenen',
#  'Grevby/Lekeryd',
#  'Nya Källberga',
#  'Nedre skog',
#  'Frösviken',
#  'Sporrakulla Stenbrott',
#  'New model army väggen',
#  'Lisö',
#  'Storvreten',
#  'Mallorca',
#  'Halmstad',
#  'Svampstället',
#  'Kanalklippan',
#  'Billingen',
#  'Plan 10',
#  'Sprängväggen',
#  'Boroberg',
#  'Maverick',
#  'Burmaklippan',
#  'skogensöga',
#  'Rövargrottorna',
#  'Hemtjärn',
#  'Marstrand',
#  'Hulta stenen',
#  'Mölnvik',
#  'K�llsberget',
#  'Radioväggen',
#  'Tyesö',
#  'Hälleborg',
#  'kallsberget',
#  'Västra Frölunda',
#  'källaren',
#  'Stegeborg',
#  'Ljugaren/Hallberget',
#  'Bleket',
#  'Orminge',
#  'L. Essingen',
#  'Centramassivet',
#  'mediamart/aberblocket',
#  'Fredriksvik',
#  'Hitorp',
#  'Sunnan',
#  'astra-gärtuna',
#  'Flaten',
#  'Sjötorp',
#  'håkmark',
#  '�berget',
#  'Simonsberget',
#  'ängen',
#  'falun',
#  'TKAK',
#  'Skogsblocket',
#  'Frösön',
#  'tumba - brosjön',
#  'Sörbo',
#  'Tyresö-Flaten',
#  'Djura',
#  'Hållundaröd',
#  'Gamla VO',
#  '"de små"',
#  'Masterdal',
#  'Falla',
#  'Skjälefjell',
#  'Stora skramsö',
#  'Nedre Midskogs',
#  'Bollebygd - Hestra',
#  'Blocket i Utby',
#  'Dyviksudde',
#  'Afrikastenen',
#  'Kolbyttemon',
#  'nynasham',
#  'Ångbåtsbryggan',
#  'Idhult',
#  'Torp',
#  'Gustavbergs Vattentorn',
#  'Råssö',
#  'Tjørnbro',
#  'Luppiovaara',
#  'Oslättsfors/Gävle',
#  'Varggården',
#  'Jonsbo',
#  'Sektor D3',
#  'Almedal',
#  'Skjutvallen',
#  'Hästväggen',
#  'Plan 13 / Valmet',
#  'Velamsund',
#  'Nedre Skog /Falun',
#  'Källsberget',
#  'Korridoren',
#  'askims överåsväg',
#  'Boxvik',
#  'Jävre',
#  'SS',
#  'frösöberget',
#  'Knivsta',
#  'Rörmyrberget',
#  'Högsby',
#  'stora skramsö',
#  'Västra Lindås',
#  'vaggeryd',
#  'Olberget',
#  'Predriksstolen',
#  'Geta',
#  'Skärmarbodabergen',
#  'Dödlarsberget',
#  'örnberget',
#  'focksta',
#  'karlberg',
#  'Norra Gryta',
#  'Sveavagen',
#  'solna brandstation',
#  'inomhus',
#  'Övre hylteberget',
#  'Ny hemlig',
#  'getå',
#  'Tj�rnbroklippan',
#  'landvettersjön',
#  'stuveröd',
#  'Stocksund',
#  'Bjurviksberget',
#  'Hockren',
#  'Solvik',
#  'stå start till the gimp',
#  'Hestrastenen',
#  'Sektor J2',
#  'Björnblocket',
#  'Solklippan',
#  'hemlig',
#  'möndal',
#  'Västra Syninge/Rimbo',
#  'Filadelfia',
#  'Mörrösjölia',
#  'Kaprifolväggarna',
#  'fjärdhundra',
#  'Perstorp / Kløva Stena',
#  'gladåker',
#  'Testoverhænget',
#  'bondberget',
#  'klven',
#  'hofors',
#  'Fituna',
#  'Svartgöl',
#  'södertäljevägen',
#  'vårhallarna, simrishamn',
#  'Nä. men jeppe',
#  'Granebergsklippan',
#  'Ringla',
#  'Tocken',
#  'Skravel',
#  'Lövnäs',
#  'Rejmyreztenarna',
#  'Sjöutsikten',
#  'Burträsk',
#  'Kajehallar',
#  'Bjuröklubb',
#  'Virsbo blöjblocket',
#  'Jakobslund',
#  'Tipp Topp Blocken',
#  'Grytån',
#  'SAltå kvarn',
#  'Lilla Mörtvik',
#  'Mörkberget',
#  'boh',
#  'Skomakarberget',
#  'Rosendal',
#  'Gladåker/Bålsta klippan',
#  'Vikskile',
#  'Rigor',
#  'ängbyplansblocket',
#  'Tovehult',
#  'deje',
#  'Gustafbergs vattentorn',
#  'lökeryd',
#  'Pålstorp',
#  'luppio',
#  'Hakered',
#  'Örsjön',
#  'källberget',
#  'Wäsaberget',
#  'Ørnberget, Sthlm',
#  'tavelsjö',
#  'haller',
#  'risebo',
#  'Alingsås',
#  'Bunnerstjärn',
#  'Skeviks grotta',
#  'Ugly you',
#  'D�dskalleberget',
#  'Tjörnbro',
#  'Runsa',
#  'Uvaberget',
#  'Skansberget',
#  'jernforssen',
#  'Bilprovningen,Karlshamn',
#  'Simonsberget (Tunaberg)',
#  'Kevleberg',
#  'I 13',
#  'tjornbroklippan',
#  'Hammardammen/Hofors',
#  'Älvkarleby',
#  'svarthögen',
#  'Tulboden',
#  'DDT-väggen',
#  'Mosjön',
#  'Hässelby strandsva',
#  'Korslöt golfbana',
#  'Secret',
#  'fruberget',
#  'Tjørnbroklippan',
#  'Härlanda tjärn',
#  'Hällefors',
#  'Bistaberget',
#  'Sjöviken',
#  'Skevik',
#  'Katrineholm',
#  'Sjukhuset, Eskilstuna',
#  'Almenäs',
#  'Loftahammar',
#  'Skotapparsten',
#  'Kaisenjarga',
#  'Aspen',
#  'milboblocken',
#  'Norra Gryta, Västerås',
#  'Chironico',
#  'Tyresö',
#  'Safjället',
#  'Högbo/gävle',
#  'Halsö',
#  'Tranås boulders',
#  'Rörmosseberget',
#  'Gränsen',
#  'latinoblocket',
#  'Norrland',
#  'Rian',
#  'Prosteberget',
#  'hok',
#  'uppsala',
#  'Navars block',
#  'Rummablocken',
#  'Motörheadblocket',
#  'Omsberegt',
#  'Burvik',
#  'Maramö',
#  'Surfväggen',
#  'Skaftl',
#  'Klutmark',
#  'Uringe',
#  'råsklippan bouldern',
#  'Uvklitt',
#  'Vika',
#  'Wapiti',
#  'Steninge',
#  'Havskogen, Väddö',
#  'V-by Fornborg',
#  'Ludvika',
#  'Rullsand',
#  'Biskopsnäset Ludvika',
#  'i skogen',
#  'blocX',
#  'Snibe Stua',
#  'Trollholmen, Hälsö',
#  'Möttja',
#  'Ulvåsen',
#  'Dyviksudd',
#  'X100',
#  'Palstorp',
#  'Toftbyn',
#  'lidingö',
#  'Trollberget, Norrköping',
#  'Finnböle',
#  'Lillån',
#  'Slättadamm',
#  'Finrummet',
#  'lappkärrsberget',
#  'skravl',
#  'Plan 13 - Hjälmen',
#  'skoggaz',
#  'Jägarhyddan, Rimbo',
#  'Hyltebergen',
#  'Nyberget',
#  'Sektor J4',
#  'Gaisenjarga',
#  'Järnberget',
#  'Skaftö',
#  'Åberg',
#  'Gothenburg',
#  'Björkdalen',
#  'trollskogen tullinge',
#  'bräkne-hoby',
#  'Norra berget',
#  'Mellby',
#  'Marnäs',
#  'mellanvalsan',
#  'Vassbäcksblocket',
#  'Hölö skog',
#  'Buråsen',
#  'Skärkäll',
#  'Olofslund',
#  'lötsjöbouldern',
#  'Grankullen',
#  'Sumpanbouldern',
#  'årjäng',
#  'Granitgråttan',
#  'garpendans',
#  'borgväggen',
#  'Viltstigen',
#  'smedjebacken',
#  'Rejmyre',
#  'Greggered',
#  'Källberga Hygget',
#  'Sandhamn',
#  'Skärsjöstenen',
#  'Tuntorpväggen',
#  'Järvön',
#  'Skedloberget',
#  'Ulvshyttan',
#  'sörbo/falun',
#  'Udden',
#  'Sollentuna',
#  'Gullmars brygga',
#  'idhult',
#  'Skogsblocket/Trollbo',
#  'Vadema Hall',
#  'Örnberget',
#  'Ågesta, Ågestahill',
#  'Falkasjön',
#  'Idkerberget/Sången',
#  'Caféblocket',
#  'Skeda udde',
#  '1-7',
#  'Gotland',
#  'Brunstorp',
#  'Ryssgraven',
#  'Forsby',
#  'valöarna',
#  'Lilis Backe',
#  'sandsjöbacka',
#  'Deje',
#  'Åker',
#  'Korpaberget',
#  'Bottna',
#  'Farmenblocket',
#  'Beatelund',
#  'Välaberget',
#  'nynashamn',
#  'Enviken',
#  'Snugge',
#  'Sydkoster',
#  'flaten',
#  'Stenkyrka',
#  'Nove',
#  'Kilnäset, Kalix',
#  '...',
#  'Aberblocket',
#  'Källbergahygget',
#  'Ostbågen',
#  'Ågest',
#  'Lilla berget 1',
#  'bladmyran',
#  'Älvnäs',
#  'Krossberget',
#  'Gryts skärgård',
#  'Stensholm',
#  'korpklev',
#  'Västerkvarn',
#  'Skälefjäll',
#  'Gransjölandet',
#  'lekparken',
#  'Tjörnbron',
#  'Lackarbäck',
#  'Lakene',
#  'Hållsunga',
#  'Vestervik',
#  'Sidsjön',
#  'filipstad',
#  'Schweden',
#  'Gubbamalen',
#  'Korslöt',
#  'Brändön/Luleå',
#  'Starrberget',
#  'Tollarp',
#  'Silverberget',
#  'Amsberg',
#  'Ässkog',
#  'Fornborgsberget',
#  'Stenarna',
#  'The Swine',
#  'Ramnäs',
#  'Brusala',
#  'Blad..',
#  'Sjötaket',
#  'Brudis',
#  'Tunaberg',
#  'Norrmjöle',
#  'GA:Södertäljevägen',
#  'kvarntäkt/Toftbyn',
#  'Rösås',
#  'åkers',
#  'Sjøtorp',
#  'Ulvås',
#  'skevik',
#  'Klus-Balsthal',
#  'Babylonien',
#  'korsningen',
#  'Skilsmässostupet',
#  'Häggsjövik',
#  'Vassbovik',
#  'Pilbo',
#  'Bohus',
#  'Ovanför Ravinen',
#  'Turbo',
#  'Centralmassivet',
#  'Silverväggewn',
#  'Trollgubben/Värmdö',
#  'ängbyplan',
#  'N',
#  'Uskedalen',
#  'Tjörn/Solklinten',
#  'Köpegårda',
#  'Brandbo',
#  'fornborgsberget',
#  'Nacksta',
#  'Gotteborg island',
#  'Falkberget',
#  'Vättekullen',
#  'Bergsjön, Ghettobouldern',
#  'Forsby, Västerås',
#  'lilla vårdberget',
#  'fjellbacka',
#  'Solvik stockholm',
#  'Möhättan',
#  'Trödjegropen',
#  'Älvbroklippan',
#  'Gritstoneblocket',
#  'Utskog',
#  'Nockeby',
#  'Graveyard-blocken',
#  'Bestorp',
#  'viks kile',
#  'Ramonesklippan',
#  'Lassehaga',
#  'Uggelberget',
#  'Kinnekulle camping',
#  'IKSU',
#  'Borgehall',
#  'Traversblocket',
#  'Unavngiven klippe',
#  'sjöända',
#  'Västervik/ vo',
#  'Älvsbroklippan',
#  'Hygget',
#  'elverksklippan',
#  'Dagcenterstenen',
#  'nacka sjukhus',
#  'Sebulba/VO',
#  'Dog rock',
#  'Risebo',
#  'Brione',
#  'Münchenbryggeriet',
#  'Vallda',
#  'Kus-tjärn',
#  'gamla södertäljeväggen',
#  'Gesunda',
#  'St. Höberg',
#  'Amundön',
#  'Målsryd',
#  'gamlestan',
#  'Tunntorpväggen',
#  'Fjällbackan',
#  'nåsten',
#  'oldberget',
#  'Sloptraversblocket',
#  'Gryta S',
#  'Branta trappan',
#  'Nacka',
#  'Stickelsbrant/Värmdö',
#  'Brobyklacken',
#  'Löta',
#  'Sennen',
#  'blocket vid vägen',
#  'Härskogen',
#  'Holländerberget',
#  'Brudberger',
#  '??? Josses sommarstuga',
#  'Vägen',
#  'domen',
#  'Nya stället',
#  'K-njarga',
#  'Glömsta',
#  'botsmark',
#  'Svarttjern',
#  'Råbäcken',
#  'Segersäng',
#  'storvretsbacken',
#  'Berghamn',
#  'Ghettobouldern, bergsjön',
#  'Musberget',
#  'Partille',
#  'Gömda knallen/Värmdö',
#  'svampblocket',
#  'Bergsparksblocket',
#  'Rankullaberget',
#  'vettekullen',
#  'Film2 väggen',
#  'kleven',
#  'torp',
#  'predikstolen',
#  'högdalen',
#  'Vårberg',
#  'Harsprånget, Porjus',
#  'Korpberget vid Tynn',
#  'Bjjagården',
#  'Södraberget 2',
#  'Hullsungä',
#  'Stockkumla',
#  'K2',
#  'Nackdala',
#  'Drottningblocket',
#  'västra hamnen',
#  'Skogslyckan',
#  'Övre Östra Hylteberget',
#  'Uppland',
#  'Tockarp',
#  'häggsjövik',
#  'Krogberget',
#  'Sektor E1',
#  'Getå',
#  'Fru berget',
#  'XX trackside',
#  'hästspåret',
#  'Plan 1',
#  'höversby',
#  'Korsvika',
#  'Mr young boulders',
#  'nöttja',
#  'Övre Hylteberget',
#  'Skuruparken',
#  'Myrberget',
#  'Lilla Långevik',
#  'Edens Lustg�rd',
#  'Ed',
#  'secret spot Skåne',
#  'Landvetterklippan',
#  'Kvarntäkt',
#  'Kramnäs',
#  'Skärmabodabergen',
#  'Scarface',
#  'Karljohanlunden',
#  'Hamburgeön',
#  'Plan 2',
#  'Dalajärna',
#  'Floda',
#  'Grytorna/Alnö',
#  'Trollberget',
#  'gränna',
#  'Luossa',
#  'Klöverskär',
#  'tovehultsberget',
#  'Carstens',
#  'Nedre Skog/Falun',
#  'Åbergsstenen',
#  'Björnö, Ingarö',
#  'Lackarebäck',
#  'Sundsvall',
#  'Hofors/Robertsholm',
#  'Saltå kvarn',
#  'Korpberget, Rimforsa',
#  'Sibräcka Prästgård',
#  'Tjørnboklippan',
#  'Utsikten',
#  'Bladmyran Gävle',
#  'Gillis insteg',
#  'Trollblocket',
#  'Lexby',
#  'Utskogen, Nacka',
#  'Nora',
#  'storvretsbadet',
#  'Älvdalen',
#  'HuDDINGE SJUKUSSTENEN',
#  'majorna',
#  'Herrhagen',
#  'Niemisel',
#  'Värmdö/Dog rock',
#  'Tolarp',
#  'Grönbrink',
#  'Tisken',
#  'Karlshamns bilprovning',
#  'åberget',
#  'sveafallen',
#  'Telefonplan',
#  'Lynx/Värmdö',
#  'Nykelvicken',
#  'bälinge',
#  'Björnviken',
#  'Highball Heaven',
#  'Vansbro',
#  'Tumbaklippan',
#  'Dalkarlskärret',
#  'tullingeberg',
#  'Gunleudd',
#  'Telegrafberget',
#  'Sku',
#  'Syd Koster',
#  'Kvarntäkt/Toftbyn',
#  'Rågårdsdal.',
#  'IP-blocket/Borlänge',
#  'Lövåsen',
#  'Fregåsberget, Rällsjön',
#  'tjörn',
#  'Är jag upp än',
#  'Rörbo',
#  'Vinteviken',
#  'Alby-Nyfors',
#  'Scania, Södertälje',
#  'Midskogs nedre',
#  'Galgberget',
#  'Bläckhall',
#  'Norra ravinen',
#  'Helga',
#  'Gubben i berget',
#  'Drakväggen',
#  'Wäsabergen',
#  'Mariannelund',
#  'Karlberg',
#  'Röda Väggen',
#  'Lilla helvetet',
#  'Norr om norrköping',
#  'Lilles backe',
#  'Djursjön',
#  'Bollebygd',
#  'Myren,stavsjö',
#  'Karlskona',
#  'Haegefjell',
#  'Flugfiskestället',
#  'Spikarna/Alnö',
#  'Nedre Skog',
#  'Gökstenarna',
#  'Välseröd',
#  'Dahlsbor/Värnamo',
#  'grännaberget',
#  'Ejen',
#  'Slattefors',
#  'Helgbo',
#  'Tuntorp',
#  'kullavik',
#  'Krusboda',
#  'Trödje/Gävle',
#  'Tjurpannan',
#  'obelisken',
#  'Målaskog',
#  'ängesbyn',
#  'Haga',
#  'Uppsala/Vik',
#  'High voltagestenen',
#  'Knutby',
#  'Bloocket vid vägen',
#  'NEZ-blocket',
#  'Kango blocket',
#  'Hagsätra',
#  'grimmered',
#  'Länsmansberget',
#  'Ängesbyn',
#  'midgård',
#  'Vråkväggen',
#  'Rimbo/Jägarhyddan',
#  'Skärsviken',
#  'Uvberget',
#  'Ulåsen',
#  'grötvik',
#  'Nyckelviken/Nacka Strand',
#  'djupdalen',
#  'Fläten',
#  'Militrklippan',
#  'henriksdal',
#  'Väsa',
#  'töllsjö',
#  'Bristaberget',
#  'Ikeablocken',
#  'Sektor B6',
#  'Lötsjöbouldern',
#  'Kärsön',
#  'gärdsås',
#  'fornborgen',
#  'Gustavsbergs vattentorn',
#  'tumba - delaval',
#  'Axmar',
#  'Vid visit grottan',
#  'Mommehål 2',
#  'källbergahygget',
#  'Kulberget',
#  'Sunkblocket',
#  'nynashmn',
#  'nacka kvarn',
#  'Ravalen',
#  'bag Bja¨ragården',
#  'sok väggen',
#  'Fläten/norrköping',
#  'Brännvinsbryggeriet',
#  'Höversby',
#  'Gnarp',
#  'Örnbacken',
#  'heby',
#  'Tranås Boulders',
#  'Stora klippan',
#  'Hållstablocket/Eskilstuna',
#  '113',
#  'Högklitt',
#  'Trångsund',
#  'VHS blocket',
#  'Svarthögen',
#  'Kolmården',
#  'Hallstaberget',
#  'Doskalleberget',
#  'Lottbosjön',
#  'Morarna',
#  'Örebro',
#  'Bro',
#  'Igelboda',
#  'Örn',
#  'C-3',
#  'Hästberget',
#  'Östnoraberget',
#  'Edens Lustgård',
#  'Uddeuddberget',
#  'Sektor F5',
#  'storablocket/Dagslöta',
#  'Höghus',
#  'Vägg2',
#  'Sunntjärnen',
#  'Morarna/Gålö',
#  'brahehus',
#  'Häller',
#  'Öckerö',
#  'bloc x',
#  'Skatås',
#  'Högosta',
#  'TKak',
#  'Blå Mal',
#  'Stensjöfjället',
#  'Hyppeln',
#  'Fiskebäckskil',
#  'Stora överhänget',
#  'Klövberget',
#  'Håkmark',
#  'Nackanäs',
#  'Junibosand',
#  'vikdal',
#  'Gamla tippen',
#  'Ringvägen / Nynäshamn',
#  'telefonplan',
#  'Torsten',
#  'Filipstad',
#  'Tångebacken 1',
#  'Skredsvik',
#  'Linghed',
#  'Omsberget',
#  'Grottberget',
#  'Torsebro',
#  'Tjurklyftan/ Hornmonstret',
#  'Gamla vo',
#  'Trävattna',
#  'Nynaäshamn',
#  'Vinterberget',
#  'Lilla Bärsta',
#  'wintjes block',
#  'safjället',
#  'Ghettobouldern',
#  'Bistberget',
#  'Luppioberget',
#  'Radsklippan',
#  'Hamra Grustag',
#  'Källberga',
#  'Eskilstuna',
#  'Hemliga klippan',
#  'Ramnalset',
#  'Sibräcka prästgård',
#  'Brappersberget',
#  'stenarna',
#  'Lysningsbadet',
#  'Sibräcke',
#  'Henriksdalsklippan',
#  'Österödsberget',
#  'Strömma',
#  'Rödberget, Flugebosjön',
#  'Grötvik',
#  'Bjönfallet',
#  'Ljugaren/Born',
#  'Lilla galten',
#  'GREBO',
#  'Kyrkviksklippan',
#  'Sk.',
#  'Latinoblocket/ Heby',
#  'hästberget',
#  'Starberget',
#  'krogberget',
#  'För forna klätterfantaster',
#  'Fjälbo',
#  'Fruberget, Stockholm',
#  'mauritzholm',
#  'vårdberget',
#  'St Höberg',
#  'gärtuna-astra',
#  'NYckelviken',
#  'Hykjeberget',
#  'Blocklands',
#  'Kyrkeslätt',
#  'Forsby Gävle',
#  'stora stenen persmåla',
#  'Rudalen',
#  'kvarnekas',
#  'Vänstra delen',
#  'Tallsjö',
#  'Åberget',
#  'Lilla Bästa',
#  'Björkeberget',
#  'Roffans svamp ställe',
#  'vo stenarna/sjöstenen',
#  'plan 4',
#  'Djurgårdsblocken',
#  'gotteborg island',
#  'Ökberget',
#  'Sandfors',
#  'Houdini',
#  'Erikslund, Media Markt',
#  'Kvarnekas. Dals-Ed',
#  'Skönstavik',
#  'Östra sjukhuset',
#  'Fjällnora, Uppsala',
#  'Blommstertornet',
#  'Överums blocken',
#  'Sylarna',
#  'Hågeby',
#  'Hoversby',
#  'skärsviken',
#  'Lilsjön',
#  'Korpberget',
#  'Lillhagen',
#  'Kvark',
#  'Bergparksblocket',
#  'döskalleberget',
#  'Oslättsfors',
#  'Ranboberget',
#  'Hällaryd',
#  ...}

# %% [markdown]
# ## · String cleaning

# %% [markdown]
# Lowercase

# %%
def lower_array(a):
    return [(str(word)).lower() for word in a]

# %%
crags_low = lower_array(crags)
myset2 = set(crags_low)
len(myset2)
# Out:
# 2345

# %% [markdown]
# Remove accents

# %%
def strip_accents(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')

def strip_accents_array(a):
    return [strip_accents(str(word)) for word in a]

# %%
strip_accents('qué pach¢aà neeng')
# Out:
# 'que pach¢aa neeng'

# %%
crags_strip = strip_accents_array(crags_low)
myset3 = set(crags_strip)
len(myset3)
# Out:
# 2307

# %% [markdown]
# Remove punctuations

# %%
def remove_punct (s):
    # replace - and / by space
    s0 = s.replace('-', ' ').replace('/', ' ')
    
    # replace 2+ spaces by 1 space
    t = re.compile(r"\s+")
    s1 = t.sub(" ", s0).strip()
    
    # remove punctuations
    s2 = re.sub(r'[^A-Za-z ]+', '',s1)
    
    # remove first space   
    s3 = re.sub('^\s', '',s2)

    # remove last space   
    s4 = s3.rstrip()
    
    return s4

def remove_punct_array(a):
    return [remove_punct(str(word)) for word in a]

# %%
remove_punct(" Éramos   pocos y       ,)?7df ri9ío la abuela#")
# Out:
# 'ramos pocos y df rio la abuela'

# %%
crag_punct = remove_punct_array(crags_strip)
myset4 = set(crag_punct)
len(myset4)
# Out:
# 2233

# %% [markdown]
# Remove first "el, la, the"

# %%
def remove_first_the(s1):
    return [re.sub('(?:^|(?:[.!?]\s))(the |el |la |las |los )', '',word) for word in s1]

# %%
cleaning_function(["los dias","las noches"])
# Out:
# ['dias', 'noches']

# %% [markdown]
# #### We put all together in one function

# %%
def cleaning_function(a):
    '''
    function used for clining a list of strings    
    '''    
    a1 = lower_array(a)
    
    a2 = strip_accents_array(a1)
    
    a3 = remove_punct_array(a2)
    
    a4 = remove_first_the(a3)
    
    return a4

# %%
cleaning_function([" ·el!$% %$CaStor ·de flor$es "])
# Out:
# ['castor de flores']

# %% [markdown]
# Using the new class created

# %%
txt = text_processor()
txt.cleaning_function(crags_strip)
# Out:
# Initialized text_processor class
# ['sjoanda',
#  'gubben i berget',
#  'tjornbroklippan',
#  'seglora',
#  'aspen',
#  'utby',
#  'svanvik',
#  'vastervik',
#  'hylteberget',
#  'viks kile',
#  'korpaberget',
#  'vindon',
#  'tollsjo',
#  'rasklippan',
#  'nacka kvarn',
#  'kjugekull',
#  'flaten',
#  'farsta',
#  'brudberget',
#  'uringe',
#  'agelsjon',
#  'dynestad',
#  'gunnilse',
#  'lexby',
#  'munchenbryggeriet',
#  'hogdalen',
#  'ekstubbeberget',
#  'gaseborg',
#  'dodskalleberget',
#  'kulberget',
#  'kullaberg',
#  'kallsberget',
#  'hundberget',
#  'niemisel',
#  'blaberget',
#  'aberget',
#  'ornberget',
#  'palstorp',
#  'solvik',
#  'stugun',
#  'bohuslan',
#  'vo stanarna',
#  'sjotorpsberget',
#  'brommaplan',
#  'nybro',
#  'dyviksudd',
#  'stennaset',
#  'traskberget',
#  'uddeuddberget',
#  'margreteberg',
#  'stegeborg',
#  'ingaro',
#  'vrakviken',
#  'hono',
#  'starberget',
#  'krokviken',
#  'norra s vall',
#  'henriksdal',
#  'skevik',
#  'midskogs',
#  'brattberget',
#  'skravelsjo',
#  'rosendal',
#  'luossa',
#  'ramberget',
#  'vulturino',
#  'orminge',
#  'alvnas',
#  'anneberg',
#  'i',
#  'kanalklippan',
#  'svarttjarn',
#  'beatelund',
#  'tunaberg',
#  'vardberget',
#  'haggsta',
#  'lillsjon',
#  'froson',
#  'lerdala',
#  'gummingbo',
#  'ekoberget',
#  'skatas',
#  'kungsten',
#  'trollbo',
#  'tosseryd',
#  'nolhaga',
#  'orhem',
#  'karson',
#  'hultberget',
#  'hygget',
#  'langholmen',
#  'fjardhundra',
#  'noret',
#  'ringkallen',
#  'rankullaberget',
#  'edens lustgard',
#  'sjoanda',
#  'tumbaklippan',
#  'soffabacken',
#  'nan',
#  'ryssgraven',
#  'tkak',
#  'kahog',
#  'idhult',
#  'finnsvedsberget',
#  'gronbrinksberget',
#  'ostnora',
#  'sifferbo',
#  'vallberget',
#  'malstena',
#  'nolby',
#  'enskallaboberg',
#  'jarnforsen',
#  'ny klippa',
#  'kiruna',
#  'agesta',
#  'hummelstad',
#  'galgberget',
#  'morarna',
#  'getakyrka',
#  'forsby',
#  'brommaplan',
#  'enkallaboberg',
#  'tumbo',
#  'ramnaslatt',
#  'rankulla',
#  'arjang',
#  'korpberget',
#  'brandstationen',
#  'gustavsberg',
#  'nockeby',
#  'grebo',
#  'bredared',
#  'fjallbo',
#  'hult',
#  'dalkarlskarret',
#  'solsidan',
#  'valstadberget',
#  'silverberget',
#  'simonsberget',
#  'virsbo',
#  'bracke',
#  'trollevagga',
#  'hallsunga',
#  'nynashamn',
#  'dodlarsberget',
#  'torsebro',
#  'morkberget',
#  'kyrkviksklippan s',
#  'bistaberget',
#  'algnas',
#  'toltorp',
#  'brappersberget',
#  'larsboda',
#  'vinterbro',
#  'nasten',
#  'braboklacken',
#  'lilla essingen',
#  'aborrtjarn',
#  'valberget',
#  'myggstenen',
#  'skallaberg',
#  'gesunda',
#  'gryta',
#  'flemmingsberg',
#  'fullbroberget',
#  'sodraberget',
#  'hemliga klippan',
#  'hakered',
#  'bjorsater',
#  'mellby',
#  'tunnelutloppet',
#  'obbola',
#  'fiby',
#  'hundberget',
#  'sodermalm',
#  'brotorp',
#  'stora skramso',
#  'stromma',
#  'skiftinge',
#  'hemsjon',
#  'byrum',
#  'fru berget',
#  'predikstolen',
#  'aberget',
#  'hulteberget',
#  'oppala',
#  'bergparksblocket',
#  'garpedans',
#  'socke',
#  'filadelfia',
#  'bergafjarden',
#  'jonsered',
#  'kraftstenen',
#  'kolartorp',
#  'brudis',
#  'haninge',
#  'fredriksvik',
#  'fjallbacka vetteberget',
#  'valaberget',
#  'abergsfortet',
#  'berga',
#  'edens lustgard',
#  'farjestad',
#  'eskon',
#  'roffans svamp stalle',
#  '',
#  'traskberget',
#  'brandon',
#  'skansberget',
#  'tasterods vatten',
#  'dye',
#  'focksta',
#  'bohus',
#  'abergsfortet',
#  'norsesund',
#  'ny klippa i tumba',
#  'ockero',
#  'goteborg',
#  'hamburgo',
#  'tjorn goteborg',
#  'sylarna',
#  'filan ingaro',
#  'trollgubben varmdo',
#  'stickelsbrant varmdo',
#  'gomda knallen varmdo',
#  'husum',
#  'holmestad',
#  'alby',
#  'wasaberget',
#  'norrang varmdo',
#  'lovasen',
#  'bjornparken',
#  'st hoberg',
#  'stacketorp',
#  'jungfruberget',
#  'landvetterklippan',
#  'sandsjobacka',
#  'ulvshyttan',
#  'mellanvalsan',
#  'greggered',
#  'i',
#  'ip',
#  'okberget',
#  'lagernberget',
#  'hoversby',
#  'javre',
#  'syd koster',
#  'dalafloda',
#  'snuggtaskeberg',
#  'uggelberget',
#  'raholmen',
#  'bispberg',
#  'kallberga',
#  'sandtaget',
#  'vistingeklippan',
#  'hemtjarn',
#  'bullaren',
#  'rodjan',
#  'brudslojans sten',
#  'eskoronningen',
#  'lynx varmdo',
#  'knutby',
#  'skansberget',
#  'flemingsberg',
#  'algarda',
#  'hedesunda',
#  'brodal',
#  'ulorna',
#  'utby',
#  'tumba delaval',
#  'rasklippan bouldern',
#  'hemliga klippan',
#  'kvark',
#  'toftbyn kvarntakt',
#  'notteryd',
#  'hakmark',
#  'varggarden',
#  'lamborn',
#  'granitgrottan',
#  'brobyklacken',
#  'paradiset',
#  'lillbullen',
#  'bjorkdalen',
#  'vrakvaggen',
#  'gnarp',
#  'gamla vo',
#  'kaisenjarga',
#  'hemlig ny',
#  'nynaashamn',
#  'knipehall',
#  'offerhallan',
#  'tuningblocket',
#  'skrackblocket',
#  'svamphagen',
#  'karljohanlunden',
#  'skahaogen',
#  'de sma',
#  'nackdala',
#  'stuverod',
#  'mr young boulders',
#  'nerforsbacken',
#  'skithusblocket',
#  'korsningen',
#  'skogens oga',
#  'navars block',
#  'lucerna',
#  'gottsunda',
#  'brudberger',
#  'nacka sjukhus',
#  'nalles trappa',
#  'gustavsbergs vattentorn',
#  '',
#  'kopegarda',
#  'berghamn',
#  'wanas',
#  'bergakungens grotta',
#  'kvarnberget',
#  'ragnhilds nasa',
#  'kyrkviksklippan',
#  'angsareten',
#  'traktorpulling',
#  'gardsas',
#  'stora galgeberget',
#  'hastberget',
#  'gardskar',
#  'flen',
#  's',
#  'gardskar gavle',
#  'k njarga',
#  'ravinen',
#  'stora berget froson',
#  'hestrastenen boras',
#  'rejmyreklippan',
#  'jarvon',
#  'bristaberget',
#  'hastberget alno',
#  'solstugan',
#  'spikarna alno',
#  'skorped',
#  'tunnel',
#  'smedjebacken',
#  'svarttjarn o vik',
#  'plan',
#  'plan',
#  'kankenvaggen',
#  'plan',
#  'broma',
#  'bouleau boche',
#  'k',
#  'ablahamn',
#  'plan',
#  'bjurviksberget',
#  'simonsberget tunaberg',
#  'haegefjell',
#  'stora berget',
#  'overhangande stenen',
#  'akers',
#  'bjorkberget',
#  'tjonbroklippan',
#  'berghuset',
#  'kroksjon',
#  'gaseborg',
#  'movie stenen',
#  'astra gartuna',
#  'gartuna astra',
#  'grotvik',
#  'hemlig',
#  'forsta stenen',
#  'areten',
#  'birger',
#  'tostado',
#  'gunbben i berget',
#  'skrattkramp',
#  'ar jag upp an',
#  'sveafallen',
#  'greggerd',
#  'svarttjarnsberget',
#  'stora klippan froson',
#  'orsjoklippan',
#  'sandhamn',
#  'ivars',
#  'rigor mortis',
#  'talludden',
#  'stone of coffe',
#  'babylonien',
#  'snugge t',
#  'hogblocket',
#  'nya berget',
#  'nylose',
#  'gaisenjarga',
#  'tavelsjoberget',
#  'rasklippan',
#  'olsberget',
#  'sebulba vaggen',
#  'uvaberget',
#  'solvik',
#  'borgvaggen',
#  'rovblocket',
#  'radholmsberget',
#  'soptippsblocken',
#  'leifsland',
#  'ramunderberget',
#  'rammberget',
#  'rodberget',
#  'rejmyre',
#  'nottja',
#  'rosas',
#  'nyhamn',
#  'runsa',
#  'garpedans',
#  'olberget',
#  'storvretsbacken',
#  'travattna',
#  'skarkall',
#  'byviken',
#  'tavelsjo',
#  'rosasberget',
#  'trollholmen halso',
#  'deje',
#  'jarna',
#  'kvarnekas',
#  'pinno',
#  'olberget',
#  'oldberget',
#  'hockren',
#  'hatet',
#  'linghed',
#  'hellesneset',
#  'en trappa upp',
#  'solna strand',
#  'stuguberget',
#  'tjuvklyftan',
#  'kalleback',
#  'henriksdalsberget',
#  'brandon',
#  'trodje',
#  'trodje gavle',
#  'trodje',
#  'norrangarna',
#  'bivacken',
#  'kolbyttemon',
#  'hakared',
#  'dahlbor',
#  'mottja',
#  'ivars kyrka',
#  'plockepinn',
#  'hille tippen',
#  'trodjegropen',
#  'ljusne',
#  'rankulla',
#  'tjuvklyftan',
#  'skogensoga',
#  'gransjolandet',
#  'silvervggen',
#  'baggis',
#  'kalvsvik',
#  'hoghus',
#  'ruddalen',
#  'tjuvkyrkeberget',
#  'uppsala',
#  'hallstaberget',
#  'soffabakken',
#  'tolered',
#  'malaskog',
#  'fiskebacksvik',
#  'frosviken',
#  'hallstablocket eskilstuna',
#  'skiftinge eskilstuna',
#  'forsby v vik',
#  'johanssecretcrag',
#  'gryts skargard',
#  'secret',
#  'dahlsbor',
#  'storstenen halna',
#  'n svalehult lillrattan',
#  'n svalehult',
#  'floda',
#  'svarthogen',
#  'djurgardsblocken',
#  'fornborgen',
#  'l essingen',
#  'hagaparken',
#  'nynas',
#  'karshult',
#  'lyse kyrka',
#  'kvarnekas',
#  'mockfjard',
#  'testoverhnget',
#  'uppsala',
#  'rasso',
#  'karshult',
#  'furukullen',
#  'tunelagost',
#  'tjuvklyftan honmonstret',
#  'fedjan',
#  'nove',
#  'tjurklyftan hornmonstret',
#  'plan',
#  'plan',
#  'plan',
#  'sjobodarna',
#  'dog rock varmdo',
#  'ekholmsnas',
#  'hulta',
#  'kugekull',
#  'milboblocken',
#  'flyttblocket',
#  'vhs blocket',
#  'hille',
#  'gavle',
#  'angbyplansblocket',
#  'liso',
#  'angbyblocket',
#  'engbyblocket',
#  'enbyblocket',
#  'angbyplan',
#  'nockby',
#  'norrland',
#  'motorblocket',
#  'milboblocken',
#  'sjtorp',
#  'stikkvag',
#  'plan  skjutvallen',
#  'safjallet',
#  'radiovaggen',
#  'not so easy',
#  'amundon',
#  'kvanjarp',
#  'gothenburg',
#  'gteborg',
#  'gaoteborg',
#  'sektor a',
#  'sektor a',
#  'sektor b',
#  'sektor b',
#  'sektor c',
#  'sektor d',
#  'sektor d',
#  'sektor f',
#  'sektor f',
#  'sektor f',
#  'sektor i',
#  'sektor j',
#  'sektor j',
#  'sollentuna',
#  'lerdala varnamo',
#  'sjotorp',
#  'langastrom',
#  'bracke',
#  'sloptraversblocket',
#  'sala',
#  'midgard',
#  'rullsand',
#  'sunkblocket',
#  'hultasteinen',
#  'kungsbacka golf',
#  'branda blocket',
#  'hugo',
#  'timmersdalakorset',
#  'almenas',
#  'fornborgen',
#  'torse',
#  'huddinge',
#  'angsareten',
#  'slagstaklippan',
#  'gritstoneblocket',
#  'furukullen',
#  'divavaggen',
#  'drakvaggen',
#  'surfvaggen',
#  'dals ed',
#  'ed',
#  'tjurblocket',
#  'linkoping',
#  'harskogen',
#  'ringvagen nynashamn',
#  'gamla vo',
#  'gamla vo',
#  'hestrastenen',
#  'baggeby',
#  'i  stenen',
#  'falun',
#  'alsten',
#  'svarthogen',
#  'geta',
#  'ronnleden',
#  'gavle',
#  'eskon gavle',
#  'sektor f',
#  'sektor e',
#  'hille gavle',
#  'landvetter',
#  'hardareblocket',
#  'blocklands',
#  'brusala',
#  'ramen',
#  'spikarna',
#  'skjutvallen',
#  'sjobodarne',
#  'dalen',
#  'hofors',
#  'carstenz',
#  'marna',
#  'falun',
#  'bokedal',
#  'branda blocket',
#  'k',
#  'valsan',
#  'nora',
#  'snugge',
#  'stora blocket',
#  'junibosand',
#  'slattefors',
#  'akerbystenen',
#  'gotteborg island',
#  'gotteborg island',
#  'tollsjoo',
#  'dahlsbohr',
#  'jarna kullen',
#  'overtanger',
#  'karlskrona',
#  'rosendel',
#  'soderhamn',
#  'djurmo',
#  'akutenstenen',
#  'akersbruk',
#  'alsten stockholm',
#  'grotvik',
#  'plan',
#  'plan',
#  'plan',
#  'tornerose',
#  'starrberget',
#  'hemlig',
#  'hogesten',
#  'ulvas',
#  'begafjarden',
#  'sundsvall',
#  'sundsvall',
#  'i',
#  'sok vaggen',
#  'supertaket',
#  'sta start till the gimp',
#  'kolsby',
#  'kolmarden',
#  'stenebygrottan',
#  'segersang',
#  'halleborg',
#  'bladmyran',
#  'nya stallet',
#  'gilltuna',
#  'skedloberget',
#  'hallaryd',
#  'kyrkeslatt',
#  'forsby vastervik',
#  'kalhygget',
#  'indianberget',
#  'midskogs nedre',
#  'haverdal',
#  'miskogs',
#  'lilles backe',
#  'lilles backe',
#  'stickvag',
#  'nacksta',
#  'udden',
#  'bostroms svampstalle',
#  'strandvagen nynashamn',
#  'midskogs nedre',
#  'gottegorg',
#  'skugekull',
#  'rormosseberget',
#  'steneby grottan',
#  'gettot',
#  'nya',
#  'segersang',
#  'alvdalen',
#  'raby',
#  'sektor j',
#  'sektor j',
#  'gettot',
#  'solklippan',
#  'hollywood',
#  'stenbykull',
#  'bjursas',
#  'himlaberg',
#  'fullbro',
#  'vattekullen',
#  'svanesvaet',
#  'valserd',
#  'svan berget',
#  'hykjeberget',
#  'duvnas',
#  'garpendans',
#  'gunleudd',
#  'kvarnekas dals ed',
#  'kvibille',
#  'sweden',
#  'klugekull',
#  'gnarpstenen',
#  'plan',
#  'plan  valmet',
#  'grottberget',
#  'grottbeget',
#  'valserod',
#  'vidja',
#  'junfruberget',
#  'tanto',
#  'lyblocket',
#  'ramberg',
#  'navars block',
#  'eljussparet',
#  'sunkblocket',
#  'kvarnekas smultronstallet',
#  'smultronberget',
#  'korsningen',
#  'uvklitt',
#  'film vaggen',
#  'skravel',
#  'edet an',
#  'karlbergsparken',
#  'tkak',
#  'lilla helvetet',
#  'josses sommarstuga',
#  'halmstad',
#  'bjornviken',
#  'trangsundsklippan',
#  'nyckelviken',
#  'sp varnamo',
#  'odensberg',
#  'tyreso',
#  'tjrnboklippan',
#  'goteborg',
#  'fiskeback',
#  'mehedeby',
#  'tkakvaggen',
#  'grnsjolandet',
#  'varnamo sp',
#  'lisesplatte',
#  'kvarnviken',
#  'ss',
#  'annero',
#  'nasteviken',
#  'alvnas ekero',
#  'sennen',
#  'finrummet',
#  'laglandet',
#  'rosendal orebro',
#  'larsoda',
#  'viby',
#  'talluddan',
#  'galgberget gotland',
#  'dhalsbor',
#  'greenlaw nb',
#  'fuskasberget',
#  'ringakallen',
#  'solleftea',
#  'farmor morrosjolia',
#  'farmor atjiken',
#  'tjurpannan',
#  'karshultvagen',
#  'norra gryta',
#  'bryggviken',
#  'navekvarns klint',
#  'tindranas',
#  'hallby eskilstuna',
#  'eskilstuna',
#  'klosan',
#  'enkopingsvagen',
#  'fituna',
#  'varnamo',
#  'karlshamns bilprovning',
#  'noresesund',
#  'harangen',
#  'vitturn',
#  'satra',
#  'hallsta',
#  'hallsta eskilstuna',
#  'hallsta',
#  'ytterhogdal',
#  'olvaggen',
#  'brintbodarna',
#  'introvaggarna',
#  'introvaggarna',
#  'burasen',
#  'kilnaset',
#  'hillevik',
#  'erikslund',
#  'safjallet',
#  'fjallet',
#  'sjotaket',
#  'galgberget gotland',
#  'jernforssen',
#  'jernforssen',
#  'sodra berget',
#  'nynashmn',
#  'nynahamn',
#  'nynashamn',
#  'nynasham',
#  'hastberget',
#  'ramsvik',
#  'nottja',
#  'bengtfors',
#  'highball heaven',
#  'roseendal',
#  'skravl',
#  'harspranget porjus',
#  'lagerbalsblocket',
#  'ornberget',
#  'hgberget',
#  'schweden',
#  'hastvaggen',
#  'flallbacka vatteberget',
#  'flallbacka',
#  'stora rejmyreblocket',
#  'stora rejmyreblocket',
#  'gronbrinkk',
#  'tegen',
#  'bootshausklippan',
#  'elefant berget',
#  'metallica stenen',
#  'afrikastenen',
#  'pilbo',
#  'maramo',
#  'uggleberget',
#  'skogen',
#  'midgard',
#  'blackhall',
#  'mitt emot sjohaller',
#  'dahlsbor sp',
#  'rigor mortisvaggen',
#  'lyse kyrka',
#  'falkberget',
#  'anrasberget',
#  'motorhead',
#  'tjorn',
#  'skravel',
#  'sorbo',
#  'ras vaggen',
#  'rasvaggen',
#  'tollarp',
#  'blommstertornet',
#  'stubun',
#  'hasslo',
#  'ryd',
#  'grycksbo',
#  'agelsjon',
#  'gettot dalsed',
#  'dals ed grottan',
#  'goteborg',
#  'blastad',
#  'blasatad',
#  'kallberget',
#  'stora klippan',
#  'krogberget',
#  'skeda udde',
#  'angbyplansblocket',
#  'akutstenen',
#  'unavngiven klippe',
#  'hofors',
#  'enkoping',
#  'dvardala',
#  'tjurpannan',
#  'tkak',
#  'gartuna',
#  'masterdal',
#  'norrviken',
#  'tumo',
#  'agesta ny',
#  'gronemad',
#  'stromstad',
#  'hulta',
#  'agest',
#  'ugly you',
#  'tovehult',
#  'korsvika',
#  'kantaberg',
#  'kyrksjon',
#  'gladaker',
#  'filipstad',
#  'sp',
#  'finnved',
#  'stora skramso',
#  'vardkaseberget',
#  'savage garden',
#  'norra ravinen',
#  'tangebacken',
#  'predriksstolen',
#  'lilsjon',
#  'mauritzholm',
#  'gustavsbergs vattentorn',
#  'doskalleberget',
#  'ostnoraberget',
#  'blaberget',
#  'sveavagen',
#  'klovberget',
#  'grittstone berget',
#  'grittstone berget',
#  'angen',
#  'klockarnas',
#  'j',
#  '',
#  'bloc x',
#  'bloc x',
#  'cafeblocket',
#  'na men jeppe',
#  'imperator',
#  'mocca',
#  'kullavik',
#  'vardkaseberget',
#  'varmdo',
#  'lillsjo',
#  'toppen',
#  'riket',
#  'iksu',
#  'balingsta',
#  'sp',
#  'agesta koblocket',
#  'agesta agestahill',
#  'hulta stenen',
#  'bjorno',
#  'utsikten',
#  'innevagg',
#  'kantaberget',
#  'gryta n',
#  'midskogsogs',
#  'huvudvaggen',
#  'ddt vaggen',
#  'n',
#  'tjorne huvud',
#  'melby',
#  'narango',
#  'kobylanylis',
#  'fjallbacka ost',
#  'cyklopen',
#  'hammarasberget',
#  'silvervaggewn',
#  'silverbergetvaggen',
#  'terrasserne',
#  'carstens',
#  'fasaskogen',
#  'utsiktsberget',
#  'mattes block',
#  'trodje gavle',
#  'bokvagenstenentullinge',
#  'skogstenen huddinge',
#  'huddinge sjukusstenen',
#  'huddingesjukhusstenen',
#  'steninge',
#  'filan',
#  'mosjon',
#  'huesa',
#  'kajehallar',
#  'oland',
#  'delsjon',
#  'ovanfor ravinen',
#  'gula vaggen',
#  'sderaasen',
#  'dagcenterstenen',
#  'almedal',
#  'vanstra delen',
#  'olofslund',
#  'sigsipamba',
#  'bananvggen',
#  'bjorbo',
#  'gladaker balstaklippan',
#  'satrablocket',
#  'stora blocket',
#  'gustafbergs vattentorn',
#  'gritstoneberget',
#  'un known',
#  'gustafsbergs vattentorn',
#  'kortebo',
#  'kanal klippan',
#  'alby nyfors',
#  'gritstoneberg',
#  'afrikastenen',
#  'solberga',
#  'kjugkull',
#  'v by fornborg',
#  'tuntorp',
#  'angbyplan',
#  'stora overhanget',
#  'chip vaggen',
#  'hitorp',
#  'b lagsvaggen',
#  'lilla berget',
#  'lilla berget',
#  'lilla berget',
#  'krondiket',
#  'forsby gavle',
#  'forsby gavle',
#  'formansdammen',
#  'soderasen',
#  'nacka kvarn',
#  'vanstra delen',
#  'hallefors',
#  'kallsberget',
#  'vala',
#  'ekoklippan',
#  ...]

# %% [markdown]
# ## · Similarity

# %% [markdown]
# If they are included into each other

# %%
def included(a,b):
    # If the word is included in a phrase
    a = " " + a + " "
    b = " " + b + " "
    if (a in b) or (b in a):
        return True
    return False

# %%
included("hola", "hola mundo")

# %% [markdown]
# If they look similar

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b, autojunk=True).ratio()

# %%
similar('hola','olo')

# %% [markdown]
# Replace by the most frequent

# %%
def replace_frequent(a,b,ls):
    '''
    Compare the ocurrences of each string of a list and 
    then returns a list with the strings replaced by the most frequent value
    '''
    if ls.count(a) > ls.count(b):
        return [a if (s == b) else s for s in ls ]
    else:
        return [b if (s == a) else s for s in ls ]

# %%
ls = ['a1','a2','a3','b', 'c', 'a', 'd', 'b', 'c', 'd', 'c', 'a', 'b','a','a1','a2','a','b']

# %%
ls_rep = replace_frequent('a1','b',ls)
ls_rep

# %% [markdown]
# Put all together

# %%
def Replace_similar_array(arr, similarity = 0.9, similarity_ask = 1, show = False):
    '''
    This functions compares every string of a list with each other and replaces if they are similar.
    It keeps the most frequent value and replaces the occurences of the other one

    input:
    arr -> np.array with the strings we want to compare
    similarity -> the similarity threshold, automatically does the correction
    similarity_ask -> this threshold asks the user if the text is similar or not before correcting
    show -> True for a results viewer

    output:
    The np.array with the similar values replaced
    '''

    str_arr = arr.copy()
    

    for index1 in range(len(str_arr)):
        for index2 in range(index1 + 1,len(str_arr)):
                            
            name1 = str_arr[index1]
            name2 = str_arr[index2] 
                            
                            
            if name1 != name2:
                inc = included(name1,name2)

                if inc:
                    str_arr = replace_frequent(name1,name2,str_arr)

                else:               
                    sim = similar(name1,name2)

                    if (sim > similarity) & (sim != 1):

                        if (show == True):
                            print("Replacing all the values with",name2,"by", name1,". Similarity: ",sim)
                        str_arr = replace_frequent(name1,name2,str_arr) 

                    elif (sim > similarity_ask) & (sim != 1):

                        print('Are they the same? (n if not) -> ', name1, " <<>> ",name2, " (", sim, ")")
                        x = input()

                        if x != 'n':
                            str_arr = replace_frequent(name1,name2,str_arr)
                            print("Replacing all the values with",name2,"by", name1,". Similarity: ",sim)


    return str_arr

# %%
# %%time
crag_sim = Replace_similar_array(arr = crag_punct, 
              similarity = 0.85, # playing a little with this similarity values found that .8 is a good value
              similarity_ask = 1,              
              show = False)

# %% [markdown]
# Thi process is quite slo, we want to make it <b> faster </b>
#
# Replacements table: We are going to create a <b>table</b> of replacements and then replace from it the original list

# %%
def replace_frequent_uniq(a,b,uniq_ls,orig_ls):
    
    freq = a if (orig_ls.count(a) > orig_ls.count(b)) else b
   
    if freq == a:
        return [a if (s == b) else s for s in uniq_ls ]
    else:
        return [b if (s == a) else s for s in uniq_ls ]

# %%
uniq_ls = pd.array(ls).unique()
ls_rep = replace_frequent_uniq('a','b',list(uniq_ls),ls)

# %%
rep_table = pd.DataFrame({'original':uniq_ls,'most_freq':ls_rep})
rep_table

# %%
[rep_table[rep_table.original == value].most_freq.values[0] for value in ls]

# %%
def replace_frequent_with_table(orig_ls,similarity = 0.85, similarity_ask = 1, show = False):
    '''
    This method is replacing the similar values of a list by the most frequent one.
    In this approach first we calculate the unique values and then we make the replacement table.
    Finally we search for the replacements of the list on this table saving us time (exponentially)
    
    input:
    orig_ls -> the list
    show -> if true it shows all the logs
    
    output:
    it returns the list
    
    '''
    arr_original = orig_ls.copy()
    
    arr_uniq = pd.array(arr_original).unique()
    
    arr_uniq_copy = arr_uniq.copy()

    for index1 in range(len(arr_uniq)):
        for index2 in range(index1 + 1,len(arr_uniq)):
                            
            name1 = arr_uniq_copy[index1]
            name2 = arr_uniq_copy[index2] 
                            
                            
            if name1 != name2:
                inc = included(name1,name2)

                if inc:
                    arr_uniq_copy = replace_frequent_uniq(name1, name2, arr_uniq_copy, arr_original)

                else:               
                    sim = similar(name1,name2)

                    if (sim > similarity) & (sim != 1):

                        if (show == True):
                            print("Replacing all the values with",name2,"by", name1,". Similarity: ",sim)
                        arr_uniq_copy = replace_frequent_uniq(name1,name2,arr_uniq_copy,arr_original) 

                    elif (sim > similarity_ask) & (sim != 1):

                        print('Are they the same? (n if not) -> ', name1, " <<>> ",name2, " (", sim, ")")
                        x = input()

                        if x != 'n':
                            arr_uniq_copy = replace_frequent_uniq(name1, name2, arr_uniq_copy, arr_original)
                            print("Replacing all the values with",name2,"by", name1,". Similarity: ",sim)
                            
                            
    
    # We create the table
    rep_table = pd.DataFrame({'original':arr_uniq,'most_freq':arr_uniq_copy})
    
    if show:
        display(rep_table)
    
    ls_orig_rep = [rep_table[rep_table.original == value].most_freq.values[0] for value in orig_ls]
    
    return ls_orig_rep

# %%
ls = ['a1','a2','a3','b', 'c1', 'a', 'd', 'b1', 'c', 'd', 'c', 'a1', 'b','a','a1','a2','a','b1',
     'a1','a2','a3','b', 'c2', 'a', 'd', 'b2', 'c', 'd', 'c', 'a2', 'b','a','a1','a2','a','b',
     'a1','a2','a3','b', 'c3', 'a', 'd', 'b1', 'c', 'd', 'c', 'a1', 'b','a','a1','a2','a','b2']

# %%
ans = replace_frequent_with_table(ls,similarity = 0.5, show = True)

# %% [markdown]
# Lets see how fast it is:

# %%
# %%time
crag_sim = replace_frequent_with_table(orig_ls = crag_punct,
                                       show = False)

# %% [markdown]
# #### ...we see that we saved a lot of time with this table method

# %%
myset5 = set(crag_sim)
len(myset5)

# %%
pd.Series(crag_sim).value_counts().head(10)

# %% [markdown]
# A big improvement respect the original:

# %%
pd.Series(crags).value_counts().head(10)

# %% [markdown]
# We now put everything inside the text_processor class

# %%
crag_sim = txt.Replace_similar_array(arr = sorted(myset5))
myset6 = set(crag_sim)
len(myset6)

# %% [markdown]
# ## · Language check

# %%
from polyglot.detect import Detector
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sentiment_analysis_spanish import sentiment_analysis

# %%
mixed_text = "La via es muy buena"
det = Detector(mixed_text, quiet=True)
print(det.language)

# %%
def Language_check(mixed_text, lang_check = 'en'):
    '''
    This function checks if the language of the text is the expected

    inputs:
    - mixef_text => text to analyze
    - lang_check => the language we want to validate

    output:
    boolean, true or false
    '''



    det = Detector(mixed_text, quiet=True)
    lang = det.languages[0].code
    conf = det.languages[0].confidence

    if (lang == lang_check) and (conf > 0.5):
        return True

    return False

# %%
Language_check("That was a good route",'en')

# %% [markdown]
# Now we use the class text_processor

# %%
txt.Language_check("La via es buenisima, y lo demas tambien",'es')

# %% [markdown]
# ## · Sentiment

# %% [markdown]
# This function will messure the sentiment of a comment

# %%
analyzer_en = SentimentIntensityAnalyzer()
analyzer_es = sentiment_analysis.SentimentAnalysisSpanish()

# %%
analyzer_en.polarity_scores("Best climb of my life")

# %%
analyzer_es.sentiment("Una escalada muy mala")

# %%
# English
def English_sentiment(sentence, analyzer_en, show = False):
    '''
    This function analyzes a sentence in english to see if it is possitive or negative

    inputs:
    - sentence => text to analyze
    - show => if its True then it will show the results 

    output:
    returns a float between +-1 whith the result 
    '''   


    vs = analyzer_en.polarity_scores(sentence)
    if (vs['compound'] != 0) and show:
        print( '----------------------------------------------' )
        print(sentence)
        print(vs['compound'])

    return vs['compound']

#Spanish
def Spanish_sentiment(sentence, analyzer_es, show = False):
    '''
    This function analyzes a sentence in spanish to see if it is possitive or negative

    inputs:
    - sentence => text to analyze
    - show => if its True then it will show the results 

    output:
    returns a float between +-1 whith the result 
    '''   

    vs = analyzer_es.sentiment(sentence)*2-1
    if (vs != 0) and show:
        print( '----------------------------------------------' )
        print(sentence)
        print(vs)

    return vs

# %%
English_sentiment("Good route", analyzer_en, show = True)

# %%
Spanish_sentiment("La via una maravilla", analyzer_es, show = True)

# %% [markdown]
# ### Language check + Sentiment

# %%
def comment_sentiment(comment, analyzer_en, analyzer_es, show = False):
    '''
    This functions takes a comment, checks the language and if its english it checks the sentiment
    input:
    - comment -> text to analyze
    - show -> if you want to show results
    
    output:
    sentiment is a value between +-1
    ''' 
    
    try:
        # Check if its in english
        is_english = Language_check(comment)

        if is_english:
            # Check the sentiment
            return Sentiment_analyzer(comment, analyzer_en, show)

        # Works for both
        is_spanish = Language_check(comment,'es')
        is_italian = Language_check(comment,'it')

        if is_spanish or is_italian:
            # Check the sentiment
            return Spanish_sentiment(comment, analyzer_es, show)            

        return 0
        
    except:
        return 0

# %%
comment_sentiment("Good route, guys", analyzer_en, analyzer_es, show = True)

# %%
comment_sentiment("La via una maravilla y lo demas", analyzer_en, analyzer_es, show = True)

# %% [markdown]
# Now we place it into the <b>class</b> in order to be able to use it in the future

# %%
txt.Language_check("Good route, guys, it was amazing")

# %%
txt.English_sentiment("Good route, guys, it was amazing")

# %%
txt.comment_sentiment("Good route, guys, it was amazing", show = True)

# %%
txt.comment_sentiment("La via una maravilla y lo demas", show = True)
