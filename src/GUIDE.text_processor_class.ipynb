# %%
from difflib import SequenceMatcher
import pandas as pd 
import numpy as np
from lib.location_class import Location
import regex as re
import unicodedata
from lib.text_processor_class import *

# %% [markdown]
# # Text processor

# %% [markdown]
# I need to create a text processor in order to:
# - Clean strings, Remove all not alphanumeric values
# - Check how similar are all words of a list and replace most frequent
# - Check the language of the comments
# - Check if a comment is possitive or negative based on the language
#
# I will include all this functions inside a class called text_processor

# %% [markdown]
# #### Retrieve the data

# %%
ascent_df = pd.read_csv('../../databases/ascent_grade_correction.csv', low_memory=False)
lc = Location(ascent_df)
# Out:
# Location class initialized

# %%
crags = lc.crags_in_country('ESP')
myset1 = set(crags)
myset1
# Out:
# {nan,
#  'VISTAMAR',
#  'risco de villarejo',
#  'Pradera del Turbón',
#  'RASICA (Carbellino)',
#  'Hces de Vegacervera',
#  'Costa Jaizkibel',
#  'sella.',
#  'castellar',
#  'sta.coloma farners',
#  'Sunbilla',
#  'Ordal',
#  'Face Est',
#  'La Pobla de Segur',
#  'canelles',
#  'El Palomar',
#  'Tarteru',
#  'yoyo-drea',
#  'Cresta del Gallo, Murcia',
#  'Dronningen',
#  'es pixarells',
#  'Buendia',
#  "Loja'",
#  'Solarium',
#  'Parga (ugo)',
#  'benabarre',
#  'Valencia del ventoso',
#  'Torcal',
#  'Peña Aragonesas',
#  "Sa font d'es rafal",
#  'Can Ximet',
#  'frontales',
#  'Arran de Batistot',
#  'Punta de Gabás',
#  'como la vida misma',
#  'muro central',
#  'bellavista',
#  'La puerta falsa',
#  'Tavernes',
#  'La  Pedriza',
#  'Peñalara',
#  'Arenas de Cabrales',
#  'Bobeda gandia',
#  'les escletxes (el papiol)',
#  'Cala varquez',
#  'Cuatrovalles',
#  'Secret Spot',
#  'el bellus',
#  'Cara sur.',
#  'Ermita de arta',
#  'la morera',
#  'castelldans',
#  'Grillons',
#  'Asombrao',
#  'La panocha',
#  'Las perchas',
#  'peña castilla',
#  'Santivañez de Bejar',
#  'Bruce Lee Buttress',
#  'Villanueva del Trabuco',
#  'cañada del capricho',
#  'radiquero',
#  'Alarcón',
#  'La Borda de Arnaldet',
#  'Berro',
#  'Mallorca Port Soller',
#  'El atico',
#  'La galería',
#  'Oto',
#  'Foradá',
#  'Els cogollons',
#  'El Cucuruxu',
#  'vilanova de meia',
#  'Peñagolosa',
#  'sa calobra',
#  'Placa de las Palestras',
#  'L´assarell',
#  'Els Estrets del Riu',
#  'nuestra señora de la peña, huelva',
#  'Bobedon',
#  'PUENTE DE LA MALENA',
#  'Café Solo',
#  'Fontanelles',
#  'las bovedas',
#  'Vermell derecha',
#  'QueBRANTAHERRADURAS',
#  'Los cortos',
#  'El Laboratorio',
#  'El Regalito',
#  'majorca',
#  'hoyamoros',
#  'l ocaibe',
#  'Cuevas del Becerro',
#  'La Creveta',
#  'La devesa',
#  'Salarates',
#  'esorial',
#  'reserva',
#  'Can  Torrat',
#  'alcañiz',
#  'La Cueva del Mar',
#  'forronias',
#  'maimon',
#  'Morata de Jalón',
#  'Peñas',
#  'olba',
#  'La grieta de la pedri',
#  'canada del capricho',
#  'Pinell de Brai',
#  'guaria',
#  "Estrets d'Arnes",
#  'Diedros del sol',
#  'Anento',
#  'onil',
#  'Ermita',
#  'desconocido',
#  'castellet de calp',
#  'Navalacruz',
#  'La lora',
#  'Porto colom',
#  'Chaos',
#  'El galliner',
#  'Somaen',
#  'vallirana',
#  'montsia',
#  'Secret',
#  'La Covacha',
#  'La Forada',
#  'el papiol les escletxes',
#  'Corme.',
#  'Lugo',
#  'La romántica',
#  'Dehesa  del olivar',
#  'Masrriudoms',
#  'POya...',
#  'Betl.lem',
#  'castellvell',
#  'atauri',
#  'Eskalette',
#  'Pared dels sacs',
#  'Gran bobeda',
#  'Es calo de betlem',
#  'Olivellla',
#  'LA PEDRIZA',
#  'el cuenco',
#  'Mallos de Riglo',
#  'grau des ruc',
#  'La martxuquera',
#  'Benasque',
#  'GRULLERE',
#  'Els Ports',
#  'Tabares, Teneriffa',
#  'Secretivo',
#  'Colomina',
#  'Escaladei Montsant',
#  'Muro sepu',
#  'Frigiliana',
#  'Castell de Santueri',
#  'cosgaya',
#  'mortixet',
#  'La placa',
#  'Crevillent',
#  'Altet',
#  'Cancho Bermejo (Valdesangil)',
#  'Manilva',
#  'Barranco de los Cernícalos',
#  'riugréixer',
#  'Premià de Dalt',
#  'Tùron',
#  'vilanova y geltru',
#  'Peña los llanos',
#  'Vandellos',
#  'xurrasko',
#  'Sant Llorenç de Montgai',
#  'corral',
#  'cantalar',
#  'Peña de los Gitanos',
#  'Cueva ribiero',
#  'Xalo / Antenas',
#  'Penyal de Sa Mel',
#  'chulila',
#  'Montanejos.',
#  'Simas de Valdecebro',
#  'villarcayo',
#  'salto del gallo',
#  'el vallecito de orihuela',
#  'Escalera arebe',
#  'font ametllo',
#  'CABRILS',
#  "Penya de l'indi",
#  'blocs de baix',
#  'El hoyo',
#  'Grau de Barrots',
#  'Escobedo',
#  'el tajo del melon',
#  'La Lleixa',
#  'La plana',
#  'super secretivo!!',
#  'Ses mosqueres',
#  'Phantom',
#  'Cingle de cacá',
#  'chuchos',
#  'Collsuspina',
#  'pets',
#  'magraner',
#  'Xàbia',
#  'navahermosa',
#  'Cala',
#  'Escletxes Papiol',
#  'Cadalso',
#  'Els gossos',
#  "S'Ermita d'Arta",
#  'Les Escletxes',
#  'Barranc de les Tines',
#  'can paluet',
#  'CAÑETE LA REAL',
#  'mallorca spain boulder',
#  'La Mula',
#  'araozt',
#  'les agulles',
#  'sarabe',
#  'Otinyar',
#  'barranc d cavalls',
#  'Foxarda',
#  'las vados',
#  "Baranc de I'avern",
#  'Apiñaniz',
#  'Laspaules',
#  'El Racó Tranquil',
#  'chaos',
#  'Sta. Mariña (Arou)',
#  'Loarre',
#  'Penyes de Gorrit',
#  'Peñiscola',
#  'El Burguillo',
#  'Castell de Can Boix',
#  'Araotz / Kobazuloa',
#  'Gandesa',
#  'Roda de ter',
#  'banyalbufar',
#  "Font d'Axia",
#  'Fígol',
#  'Key laugh',
#  'raco de tovaines',
#  'Mallorca Cala Barques',
#  'St Gadea',
#  'Bobeda de Origue',
#  'benaojan',
#  'BALTZOLA',
#  'St. Ana',
#  'lorxa',
#  'Oro',
#  'cavadas',
#  'Castillo de gayolas',
#  'Puerto ventana',
#  'Calatorao',
#  'Stanna',
#  'baléares',
#  'anguiano abueletes',
#  'Miguel Gomez, Chulilla',
#  'la bartra',
#  'El molino',
#  'Pico la población',
#  'Pereruela Zamora',
#  'alaró',
#  'Los chopos',
#  'Fondo Mas Carlus',
#  'Bosque',
#  'Unzúe',
#  'navalosa',
#  'Coves de ribes',
#  'San pelayo',
#  'figares',
#  "Font de l'Ametlló",
#  'Les Esposes',
#  'El cuervo',
#  'fuerteventura',
#  'Muro de Caimari',
#  'El coll de la barraca',
#  'Cargolaire',
#  'les saleretes',
#  'Mezalocha',
#  'Txoritokieta',
#  'Torrelles de LLobregat',
#  'atico',
#  'Curva Pequele',
#  'Andratx',
#  'son xanquete',
#  'Ca na nyic',
#  'Cèllecs',
#  'Tabares',
#  'Hoya de Pineda',
#  'Claverol',
#  'Echo valley-Polop',
#  'Cerro el viso',
#  '##',
#  "Cova de l'Ocell",
#  'Rasos de Peguera',
#  'Navacerrada/Alto del Telégrafo',
#  'margalefº',
#  'Capçanes',
#  'cacin principal',
#  'huajalotes',
#  'La Vecilla',
#  'Polideportivo. Marbella',
#  'Lugo.',
#  'Puerto Venecia',
#  'orihuela(bobeda)',
#  'la cala',
#  'Sector A',
#  'Ombreiro',
#  'zona 0',
#  'Sant Vicenç de Castellet',
#  'St.Llorenç',
#  "El morral de l'àngel",
#  'Peton do Xalo',
#  'mont sant',
#  'Estraguena',
#  'congosto',
#  'San Vicente de la Barquera',
#  'venta de juana',
#  'valdeprados',
#  'El Cenobio de Valerón',
#  'La Risca',
#  'navacerrada',
#  'Juanma',
#  'Puig den Garrafa',
#  'El Buste',
#  'campo/la ola',
#  'Las palomas',
#  'esparragalejo',
#  'Lanazarote',
#  'Boulder de Jon',
#  'Madalenaitz',
#  'SANTA URSULA',
#  'CASTILLO BAYUELA',
#  'San lorenc',
#  'La luz',
#  'Presa los Perez',
#  'Tozal',
#  'Balneario',
#  'Porrones ridge',
#  'ruaba',
#  'La Foradá',
#  'Dique',
#  'Avenc',
#  'el burguillo',
#  'El turon',
#  'Cerro del Bu',
#  'Sorralta',
#  'three corners',
#  'Toix',
#  'la zona x',
#  'pena puerta',
#  'Cervelló',
#  'Veredilla',
#  'El altet',
#  'Punta Nariga',
#  'las barbas de san pedro',
#  'cañon de boos',
#  'TABARES',
#  'La Pedricita',
#  'Berdorf',
#  'Mas Carlús (Pantà de Foix)',
#  'tierga',
#  'atalaya',
#  'san fausta',
#  'hongos',
#  'Arico Nuevo',
#  'cueva del Edwards',
#  'Julian Muñoz',
#  'Telegrafo',
#  'penedès',
#  'la boveda de cristal',
#  'el hondon',
#  'Echo Vally',
#  'Racó tranquil',
#  'Vinya nova',
#  'La Población',
#  'Segundo Hermanito',
#  'Agost',
#  'Presa do Eume',
#  'Madrid',
#  'Pandera',
#  'Caldas de Reis',
#  'Hondón',
#  'Valdegovía',
#  'Guadalajara',
#  'Sector central',
#  'piedrachecha',
#  'León',
#  'La atalaya.cartagena',
#  'Penyal des Grau',
#  'castell de santueri',
#  'Montserrat',
#  'Les coves de Ribes',
#  'coll pique',
#  'Laja Roja de Chafa',
#  "Castell S'Espasa",
#  'cogollos',
#  'Alto del telégrafo',
#  'Gorges Du Tarn',
#  'Salto de la cabra',
#  'Los Alcores',
#  'Es caló de betlem.',
#  'hudidero',
#  'serra engarceran',
#  'Grau el Matxos',
#  'cerro corona',
#  'Mordor',
#  'Arco de Valdeteja',
#  'El Brull',
#  'Tres ponts',
#  'Gorg blau',
#  'alfacar',
#  'Figares',
#  'Vilanova de Meiá',
#  'Foz de la canal',
#  'arboi',
#  'CHIVA',
#  'COGUL',
#  'vilanova y la geltru',
#  'piri frances',
#  'beceite',
#  "Mas de l'escola",
#  'Cantabria',
#  'El Porís',
#  'Coscolla',
#  'can boquet',
#  'Vegacervera',
#  'Cingle de Cacàc',
#  'Qusada',
#  'Penyal de sa mel',
#  'Moixent',
#  'Roques de cosdevia',
#  'Carrtajima',
#  'La Concagua',
#  'vadesangil',
#  '¿?',
#  'Cazorla',
#  'St.sulles',
#  'La peñona',
#  'estepa',
#  'sanfausto',
#  'Torcalito, Malaga',
#  'sierra alhamilla',
#  'La Puebla de Albortón',
#  'el torcon',
#  'Olina',
#  'sierra engarcelán',
#  'la ñora',
#  'Entrepeñasñas',
#  'El kaos',
#  'Las Vegas, Tenerife',
#  'Bentúe de Rasal',
#  'la panocha',
#  'Albarracin terra media',
#  'Sol y sombra ibiza',
#  'pinell de brai',
#  'Rabanal',
#  'Congosto de ventamillo',
#  'fuendetodos',
#  'Vilajoiosa',
#  'El Trankeru',
#  'Coggolos',
#  'es burgar',
#  'algamitas',
#  'Las Txarras',
#  'Vallès',
#  '´ç',
#  'Barranco del Tartel',
#  'cangas de  onis',
#  'Virgen de la Nuev',
#  'Sinbad Gully',
#  'Tres Ponts',
#  'El xaquetó',
#  'Infierno',
#  '7c+',
#  'la Plana',
#  'Collada de Carmenes',
#  'cèllecs',
#  'el torozo.',
#  "ca'n marvel",
#  'kanpezo',
#  'tajo del abanico',
#  'Barranc del Curt',
#  'secret blocs',
#  'Villanueva de Valdegovia',
#  'peña roja-Xalo',
#  'Sta Mariña',
#  'San Marcos (Rentería)',
#  'mas maslur',
#  'granja san ildefonso',
#  'Horta de san joan',
#  'Espadalles',
#  'congosto ventamillo',
#  'bovedon de gandia.',
#  'Las Perxas',
#  'Rabanal de luna',
#  'Tajo de Espantaperros',
#  'Revisa',
#  'Montblanc',
#  'Peña Castellon',
#  'Cuanca',
#  "cova d'almenara",
#  'jugoslavia',
#  'New Northumberland',
#  'Cala Ferrera',
#  'Peña de fresnidiello',
#  'Sot de la guillota',
#  'Lanzarote',
#  'Cotón de Lancara',
#  'Fania',
#  'Zumaia Getaria',
#  'Cañada del Capricho',
#  'OLBA',
#  'Leyva',
#  'Son cavaspre',
#  'savassona',
#  'iturmendi',
#  'El Papiol',
#  'Torretxiki',
#  'RISCO de SANTIBÁÑEZ (Salamanca)',
#  'roca de Les hores',
#  's',
#  'Coll de la Barraca / Penyes de Salomo',
#  'Píñar',
#  'L`anell',
#  'Mont-Rebei',
#  'Vista',
#  'alange,Merida',
#  'Soria',
#  'S.de Luna',
#  'pinares de san anton',
#  "clot d'en goda",
#  'Sierra blanca, Marbella',
#  "Figols a la'Ombra",
#  'San Fausto',
#  'tarragona',
#  'Hoyo',
#  'mascun-las ventanas',
#  'Castell d´Alaro',
#  "s'outlet",
#  'Penya Almarra',
#  'cova de les cabres',
#  'Risco Moreno del Hornillo',
#  'Cala Mitjana',
#  'cueca',
#  'Ráfales',
#  'Caldas De Reis',
#  'Finisterre',
#  'Peñon de Benalauria',
#  'Rocas del Ignasi',
#  'Matienzo',
#  'Vistamar derecha',
#  'Patiras',
#  'Tossa de Montbui',
#  'El Algar',
#  'el cenobio',
#  'Cortijo',
#  'ligüerzana',
#  'Sagasta',
#  'Cabeço gordo',
#  'V.del Rosario',
#  'ccra',
#  'Horta de s.juan',
#  'mijas',
#  'penya del moro (begues)',
#  'Xaragall Del Foió',
#  'Ocaive',
#  'Las tuerces',
#  'Yecla - La Magdalena',
#  'La marea',
#  'es burga(escorca)',
#  'pto soller',
#  'El anden',
#  'test',
#  'Grado del pico',
#  'Manera de Vivir',
#  'Cuevaboyu',
#  'SEGÜENCO',
#  'Cañon del sil',
#  'arico/la curva',
#  'la pauta',
#  'Las perxitas',
#  'Cueva de arucas',
#  'El río',
#  'Valdeagobia',
#  'La Cova del Ocell',
#  'Cartajima',
#  'piñar',
#  'Peña maria/Gestalgar',
#  'mosaiko',
#  'OLVENA',
#  'Saint Llorenc de Montgai',
#  'Adzaneta',
#  'Racó de Cortes',
#  'Ramales',
#  'Carrasca',
#  'Santamera',
#  'Desplome de las Bujarras',
#  'Valdesangil',
#  'Liguerzana',
#  'Castellar del Vallès',
#  'lapedriza',
#  'peñon mitico',
#  'El Recodo',
#  'montmelo',
#  'Alós de Balaguer',
#  'Mister Hanky',
#  'BARRUECOS',
#  'El Campo',
#  'Fisterra',
#  'El Vendrell',
#  'Tunte',
#  'Liscar',
#  'Las monjas',
#  'Valle del Turón',
#  'El Gruyere',
#  'añavieja',
#  'Valle de Tena',
#  'el papiol',
#  'Pigpunyent',
#  'Montgat',
#  'Valdiello',
#  'La Cova del Oceill',
#  'Huéscar',
#  'Montbru',
#  'Piedra sechin',
#  'Las peñitas',
#  'BuSTARBIEJO',
#  'La Baga',
#  'Arico arriba',
#  'Vallecito',
#  'L. C.',
#  'Frenidiello',
#  'St Llorenç de Montgai',
#  'buron',
#  'Montmell',
#  'Chanteiro',
#  'Penya del Corb',
#  'El Telegrafo',
#  'san martin de valdeiglesias',
#  'Aigues pases',
#  'Pedreña',
#  'SANTIBÁÑEZ de BÉJAR (Salamanca)',
#  'Secret area',
#  'Pardinella',
#  'calomarde',
#  'san pelegrín',
#  'Belmez - Cueva fosforita',
#  'Montejaque',
#  'Vilanova i la Geltrú',
#  'Raco de tovaines',
#  'Mal Pas',
#  'Felechosa',
#  'Martinez (Puerto Cruz)',
#  'rasika',
#  'arenas de cabrales',
#  'ager',
#  'R de capellans',
#  'La silla',
#  'rocadura cavallers',
#  'La Granja',
#  'Benahocaz',
#  'Sant benet',
#  'Techo de la Devesa',
#  'tazones',
#  'Ripoll',
#  'ELs Cogullons',
#  'blok del pork',
#  'els cogollons',
#  'nupzia',
#  'FONT SOLEIA',
#  'rajadell',
#  'Macheta',
#  'Pixarells',
#  'forronías',
#  'marglef',
#  'Álora',
#  'El salto la cabra',
#  'Callosa de segura',
#  'Port d´es Canonge / Mallorca',
#  'Siurana/ El Pati',
#  "Pont de l'Arc",
#  'Capricho',
#  'lo soterrani el jardi del roure',
#  'Caleo',
#  'La mossara',
#  'son servera',
#  'Penya del indi',
#  'SERRATELLA',
#  'Cala barques',
#  'Vallirana - Les Casetes',
#  'cuevatis',
#  'Tajos del Canjorro',
#  'Vallirana',
#  'Túnel',
#  'Alcaudete d la Jara',
#  'Piedras negras',
#  'arnedeillo',
#  'Lazo',
#  'betistumbas',
#  'Frontal',
#  'Abdet',
#  'Penya roja',
#  'lanzadera',
#  'tuero',
#  'Sombre del Leon',
#  'Sot de la Guillota',
#  'La Palma',
#  'vallecito',
#  'Valdes angil',
#  'pego',
#  'Carcauz',
#  'Huart Arakil',
#  'Santivañez de bejar',
#  'Font doncella',
#  'Ermita Virgen de la Nueva',
#  'San Antón (El Palo)',
#  'sot de la guillota',
#  'Cacàc',
#  'VY',
#  'Sa Creueta',
#  'Cortes de Pallás',
#  'Chiva/Corral de Vacas',
#  'sector dels maxos',
#  'Anies',
#  'Xon Xanquete',
#  'Chilulla',
#  'Dilar',
#  'Pico Turbon',
#  'Priego',
#  'La Ňora',
#  'Pequeña escocia',
#  'Seagovia',
#  'cañon uceda',
#  'ObAGA NEGRA',
#  'Ses Mosqueres',
#  'Villanueva del Rosario. El kaos.',
#  'Sadernas',
#  'Arteixo',
#  "Port D'es canonge",
#  'Corroncui',
#  'La Luz Moros Boulder',
#  'la foz de la canal',
#  'barranc grillets',
#  'Sena Luna',
#  'Capanna Bill',
#  'campisabalos',
#  'La rasica',
#  "L'Herbolari, Siurana",
#  'Rincon bello',
#  'La Penya del Moro',
#  'Pozo',
#  'La Graja, Jumilla',
#  'Barranco fondo',
#  'Olloniego',
#  'el buey',
#  'el mueto',
#  'kanpezu',
#  'la Soleia de Valniu',
#  'Erinya',
#  'CASTELLET',
#  'Barranc de la guitarra',
#  'Cenovio',
#  'Xalo Valley',
#  'Edén',
#  'Cau del duc',
#  'Cara Sur',
#  'Seixalbo',
#  'Xalo',
#  'barrankot',
#  'madiona',
#  'Campisáblos',
#  'coral',
#  'norte',
#  'Risco del Fraile',
#  'el centinela',
#  'rapun',
#  'La cueta',
#  'LEDESMA',
#  'penya senyal',
#  'el camino',
#  'Patones de arriba',
#  'la candelilla',
#  'Valeç',
#  'Cala Barques',
#  'Cova del Oceill',
#  'Burgos/Santa Gadea',
#  'Castell de Subirats',
#  'Vellavista',
#  'Sa Marin',
#  "L'escala de la vida",
#  'can melafots',
#  'El Planetario',
#  'Fuentidueñas',
#  'Els gegants',
#  'àger',
#  'Bagergue (Vielha)',
#  'Cañón del Sil',
#  'Calpe',
#  'bolos de orzola',
#  'fuentiduena',
#  'Es Verger / Mallorca',
#  'riscos de villarejo',
#  'aa',
#  'penalba',
#  'Amieva',
#  'Es fumat',
#  'Montes Arabí',
#  'araya',
#  'BALCO DE MAR',
#  'sabassona',
#  'Arico Nuevo / Tenerife',
#  'SAN MARTIN VALDEIGLESIAS',
#  'Órganos de Montoro',
#  'peña castibian.Monchiriguel',
#  'Saint Lorenz de Mum',
#  'Barrera valdesancho',
#  'es torrent',
#  'el coto',
#  'Cala boquer',
#  'mula',
#  'Molledo(Asturias)',
#  'oragnya',
#  'Piedras Blancas',
#  'Ampriu-Benasque',
#  'mayo de luna(cosera)',
#  'torroella de montgri',
#  'Dragonera',
#  'La jonquera',
#  'saltacaballo',
#  'can fill',
#  'La Malena (variante V+)',
#  'villalba',
#  'Sobrinos',
#  'El Castellet',
#  'alcaudete',
#  'Ruta de las fábricas',
#  'Jamilena',
#  'PLACAS SLALOM',
#  'Cubells',
#  'Ermita virgen de la nueva',
#  'Alrededores de Barcelona',
#  'Mi casa',
#  'Montbrú',
#  'El Torozo',
#  'la Cantera',
#  'Molinaseca',
#  'Fussimaanya',
#  'peña puerta',
#  'hondon de las nieves',
#  'El Buste (Borja)',
#  'quebrantaherraduras del medio',
#  'salvanebleau',
#  'orihuela',
#  'la vila joyosa',
#  'Ilaberia',
#  'Bentue de rasal',
#  'El Cerro (el torno)',
#  'Valera',
#  'Estepa',
#  'Santiago',
#  'Villanueva del Rosario. El kaos',
#  'Ligüerre de Cinca',
#  'pared de la carcel',
#  'itoitz',
#  'La pobla de segur',
#  'Basconcillos del tozo',
#  'El Solerás',
#  'las conchuelas',
#  'Ribes de Freser',
#  'desplome',
#  'Xon Xanquente',
#  'Margarlef',
#  'El torcal de antequera',
#  'Itaca / Esporles',
#  'Cancho del Mondalindo',
#  'Penya de sa mel',
#  'Baaltzola',
#  'Santa lucia',
#  'OROPESA',
#  'moclandia',
#  'rambla Bejar, lorca',
#  'Boquer',
#  'MAIN CRAG',
#  'Castellvi',
#  'La creveta',
#  'Cueva del diable',
#  'xxxx',
#  "Val des Pont d'en blei",
#  'Cohollos',
#  'Salvatierre del Esca',
#  'El barranc del viern',
#  'Valpuesta',
#  'Cala  Santanyi',
#  'arucas',
#  'Teide',
#  'Pixarells 2',
#  'Parga',
#  'St.Llorenc de Montgai',
#  'Tocho de san juan',
#  'XODOS',
#  'Olvena',
#  'cala santany',
#  'la prediza',
#  'Chaopao',
#  'colmenar viejo',
#  'Metrosexual',
#  'Barranquet de Ferri',
#  'Calhorros',
#  'Mallorca',
#  'SANT MARTI CENTELLES',
#  'El Torozo (Este)',
#  'Risco Santibañez',
#  'El bon combat',
#  'Finding Neverland',
#  'La foz de la canal',
#  'cañoncito',
#  'la comuna',
#  'racó del corb',
#  'VOBEDA',
#  'ARANARACHE',
#  'Martiánez',
#  'alicante',
#  'AlMERIA',
#  'El Cenobio',
#  'Paredon/Puig Major',
#  'Calanda',
#  'Es Calo',
#  'Malpas de Travil',
#  'collbato - els graus',
#  'Les Coves de Vinroma',
#  'peña maria',
#  'la dehesa candelario',
#  'Cova de ribes',
#  'Boyeriza',
#  'Corral Nou',
#  'Pancorbo',
#  'solarium',
#  'Huesa bermeja',
#  'Techo don pepo',
#  'Morón de la Frontera',
#  'villarejo',
#  'El santuary',
#  'congosto de ventamillo',
#  'Barredo',
#  'Ermita ulldecona',
#  'Raguchillo',
#  'Salamanca',
#  'caldueño',
#  'El picayo',
#  'Fuentes de Peñacorada',
#  'Risco Gordo',
#  'Peñon de benalauria',
#  'Escalete',
#  'Sa gubia',
#  'santibañez',
#  'rodelard',
#  'Ribesalbes',
#  'la bahia de shangai',
#  'Las Calmas',
#  'Val de Guadar',
#  'Dillingen',
#  'Bovedon de Gandia',
#  'rapún',
#  'margalef/can net',
#  'Almenara',
#  'rosildos',
#  'puerto roque',
#  'Los Agujeros',
#  'Pinollano',
#  'Zona oeste',
#  'Pe�on de Ifach',
#  'Remuñe',
#  'el bruc',
#  'Cadillac',
#  'SANTA LIÑA',
#  'Ceva Bollu',
#  'Grau de la igleixia',
#  'bentue',
#  'Pas Mala Dona',
#  'Los Vados',
#  'Bco. de Bañaderos',
#  'bikini wall',
#  'Monsetserrat',
#  'la grieta/ la pedriza',
#  'La Pedriz',
#  'el castellet',
#  'Cuenco-baléares',
#  'Pico Abadías',
#  'Frontales/El Chorro',
#  'Gombreny',
#  'carla magraner',
#  'Regeiro',
#  'Montserrat Sant Benet',
#  'montsianell',
#  'Puebla de don Rodrigo',
#  'El Marchal / Almería',
#  ...}

# %% [markdown]
# ## · String cleaning

# %% [markdown]
# Lowercase

# %%
def lower_array(a):
    return [(str(word)).lower() for word in a]

# %%
crags_low = lower_array(crags)
myset2 = set(crags_low)
len(myset2)
# Out:
# 7099

# %% [markdown]
# Remove accents

# %%
def strip_accents(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
                  if unicodedata.category(c) != 'Mn')

def strip_accents_array(a):
    return [strip_accents(str(word)) for word in a]

# %%
strip_accents('qué pach¢aà neeng')
# Out:
# 'que pach¢aa neeng'

# %%
crags_strip = strip_accents_array(crags_low)
myset3 = set(crags_strip)
len(myset3)
# Out:
# 6728

# %% [markdown]
# Remove punctuations

# %%
def remove_punct (s):
    # replace - and / by space
    s0 = s.replace('-', ' ').replace('/', ' ')
    
    # replace 2+ spaces by 1 space
    t = re.compile(r"\s+")
    s1 = t.sub(" ", s0).strip()
    
    # remove punctuations
    s2 = re.sub(r'[^A-Za-z ]+', '',s1)
    
    # remove first space   
    s3 = re.sub('^\s', '',s2)

    # remove last space   
    s4 = s3.rstrip()
    
    return s4

def remove_punct_array(a):
    return [remove_punct(str(word)) for word in a]

# %%
remove_punct(" Éramos   pocos y       ,)?7df ri9ío la abuela#")
# Out:
# 'ramos pocos y df rio la abuela'

# %%
crag_punct = remove_punct_array(crags_strip)
myset4 = set(crag_punct)
len(myset4)
# Out:
# 6507

# %% [markdown]
# Remove first "el, la, the"

# %%
def remove_first_the(s1):
    return [re.sub('(?:^|(?:[.!?]\s))(the |el |la |las |los )', '',word) for word in s1]

# %%
remove_first_the(["los dias","las noches"])
# Out:
# ['dias', 'noches']

# %% [markdown]
# #### We put all together in one function

# %%
def cleaning_function(a):
    '''
    function used for clining a list of strings    
    '''    
    a1 = lower_array(a)
    
    a2 = strip_accents_array(a1)
    
    a3 = remove_punct_array(a2)
    
    a4 = remove_first_the(a3)
    
    return a4

# %%
cleaning_function([" ·el!$% %$CaStor ·de flor$es "])
# Out:
# ['castor de flores']

# %% [markdown]
# Using the new class created

# %%
txt = Text_processor()
txt.cleaning_function(crags)
# Out:
# Initialized text_processor class
# ['arboli',
#  'montsant',
#  'siurana',
#  'chorro',
#  'port de soller',
#  'mallorca',
#  'jerica',
#  'cuenca',
#  'siurana',
#  'onate',
#  'baltzola',
#  'larraona',
#  'sella',
#  'atauri',
#  'oro',
#  'apellaniz',
#  'montgrony',
#  'etxauri',
#  'egino',
#  'patones',
#  'mallorca',
#  'rodellar',
#  'cala magraner',
#  'terradets',
#  'salem',
#  'salinas',
#  'gandia',
#  'madrid',
#  'basqueland',
#  'vilanova de prades',
#  'riglos',
#  'lliber',
#  'olta',
#  'sierra de toix',
#  'forada',
#  'escorial',
#  'pedriza',
#  'liendo',
#  'montserrat',
#  'torcal',
#  'riba',
#  'port de soller',
#  'sadernes',
#  'gandia',
#  'araotz',
#  'ramales',
#  'convento',
#  'teverga',
#  'desplomilandia',
#  'arico',
#  'cala santanyi',
#  'sestret',
#  'pelugano',
#  'montanejos',
#  'sant llorenc de montgai',
#  'sant llorenc del munt',
#  'camarasa',
#  'sa gubia',
#  'sestret',
#  'valdegobia',
#  'cahorros',
#  'loja',
#  'loja',
#  'morata de jalon',
#  'vellon',
#  'agujas rojas',
#  'cogollos',
#  'vellon',
#  'quiros',
#  'morata de jalon',
#  'valeria',
#  'canon de uceda',
#  'reguchillo',
#  'mussara',
#  'pedrosa',
#  'cueva boyu',
#  'valdehuesa',
#  'vados',
#  'espiel',
#  'tenerife',
#  'tijuana',
#  'penon de ifach',
#  'zuheros',
#  'santueri',
#  'bielsa',
#  'alquezar',
#  'pena rubia',
#  'jalon valley',
#  'bellus',
#  'puig de garrafa',
#  'blue mountains',
#  'montesa',
#  'mont ral',
#  'jaizkibel',
#  'cubells',
#  'sestret',
#  'chulilla',
#  'torrelodones',
#  'siuntiufinland',
#  'coalla',
#  'zarzalejo',
#  'penas blancas',
#  'reconco',
#  'manzaneda',
#  'vadiello',
#  'archidona',
#  'sadernas',
#  'garraf',
#  'gelida',
#  'penya ginesta',
#  'garraf',
#  'penarrubia',
#  'turon',
#  'grazalema',
#  'paparres',
#  'paparres',
#  'cabrils',
#  'margalef',
#  'barrinha',
#  'cuevas',
#  'cueva bollu',
#  'creveta maiorca',
#  'guia de isora',
#  'penahorada',
#  'valde',
#  'ibiza',
#  'gama',
#  'berga',
#  'capricho',
#  'valdesangil',
#  'hoya moros',
#  'fraguel',
#  'exauri',
#  'san bartolo',
#  'altea',
#  'can boquet',
#  'ogassa',
#  'fraquel',
#  'tivissa',
#  'grau dels matxos',
#  'colmenar',
#  'crevillent',
#  'escales',
#  'font de lametllo',
#  'calvia',
#  'penartea',
#  'san fausto',
#  'cala del moral',
#  'nan',
#  'canadas',
#  'castillo de santa catalina',
#  'salto de la cabra',
#  'cerro del canjorro',
#  'salto',
#  'desdentegada',
#  'fuixarda',
#  'valeria',
#  'otinar',
#  'traversella',
#  'valdegovia',
#  'andratx',
#  'peton do xalo',
#  'valle de abdalajis',
#  'rapun',
#  'petit paradis',
#  'savassona',
#  'navalosa',
#  'candelario',
#  'torcal de antequera',
#  'leiva',
#  'recuevas',
#  'calders',
#  'galdames',
#  'urduliz',
#  'monteferro',
#  'tuerces',
#  'alcalali',
#  'guardo',
#  'fuentes de penacorada',
#  'moia',
#  'valdesangil',
#  'solana',
#  'santa barbara',
#  'valldemossa',
#  'cuatro picos',
#  'vitor',
#  'cabezon de oro',
#  'creveta',
#  'banyadores',
#  'hoces de vegacervera',
#  'salvatierra de esca',
#  'covas',
#  'covas',
#  'tartareu',
#  'pozo verde',
#  'santa gadea',
#  'cavallers',
#  'prianes',
#  'kantera azpeitia',
#  'ontinyent',
#  'pic de laliga',
#  'hacha',
#  'bunol',
#  'santibanez',
#  'navalones',
#  'perles',
#  'cobas',
#  'cabrera',
#  'atxarte',
#  'os de balaguer',
#  'viuet',
#  'santa ana',
#  'vellon',
#  'sorrueda',
#  'mugarra',
#  'facu',
#  'castillo de bayuela',
#  'cieza',
#  'e gandia',
#  'subirats',
#  'pena pintada',
#  'benaocaz',
#  'vilanova de meia',
#  'ayna',
#  'altea col',
#  'virgen de la nueva',
#  'elbarrableau',
#  'san martin de valdeiglesias',
#  'puebla de guzman',
#  'marin',
#  'albarracin',
#  'cogul',
#  'sant joan de vilatorrada',
#  'orihuela',
#  'sant llorenc',
#  'corme',
#  'burguillo',
#  'mens',
#  'valonsadero',
#  'albarrableau',
#  'villanueva de cauche',
#  'mijas',
#  'cala del moral',
#  'pinares de san anton',
#  'torcalito',
#  'torcalito',
#  '',
#  'c',
#  'pego',
#  'puerto roque',
#  'cedrillas',
#  'alfambra',
#  'huesa del comun',
#  'mula',
#  'fataga',
#  '',
#  'cabrera',
#  'cabreras',
#  'villanueva del rosario',
#  'fuentetoba',
#  'pancorbo',
#  'coll de nargo',
#  '',
#  'vilanova',
#  'alto del telegrafo',
#  'poloria',
#  'perchas',
#  'somaen',
#  'perchas',
#  'colmena',
#  'claret',
#  'otura',
#  'otura',
#  'collegats',
#  'careses',
#  'alto del telegrafo',
#  'tamadaba',
#  'montefrio',
#  'cruz',
#  'navacerrada',
#  'lamindao',
#  'santa anna',
#  'matienzo',
#  'santa linya',
#  'fuixarda',
#  'carrascal',
#  'olvena',
#  'somaen',
#  'boyeriza',
#  'salto de la cabra',
#  'alfacar',
#  'n',
#  '',
#  'bolonia',
#  'canon del sil',
#  'valmadrid',
#  'cullar',
#  'revilla',
#  'corbera',
#  'beuda',
#  'cervera del maestre',
#  'turon',
#  'ortigosa',
#  'pena la novia',
#  'xon xanquete',
#  'cacin',
#  'culla',
#  'muela',
#  'muela',
#  'castell de santueri',
#  'arnedillo',
#  'cadalso',
#  'oliana',
#  'rio',
#  'pedriza',
#  'masriudoms',
#  'archidona',
#  'cellecs',
#  'chorro',
#  'alaro',
#  'calvia',
#  'les perxes',
#  'les perxes',
#  'port soller',
#  'puig de sa morisca',
#  'torralba de los frailes',
#  'es verger',
#  'es verger',
#  'puig de sant marti',
#  'gorg blau',
#  'mur de caimari',
#  'caimari',
#  'barranco de los molinos',
#  'vegacervera',
#  'bentue',
#  'cremat',
#  'tres ponts',
#  'abella de la conca',
#  'solius',
#  'collsuspina',
#  'sorralta',
#  'organya',
#  'entrepenas',
#  'pena de cenicientos',
#  'budino',
#  'galineiro',
#  'congosto',
#  'oulego',
#  'sezze',
#  'llaberia',
#  'penahorada',
#  'cueva liesva',
#  'villarejo',
#  'sagasta',
#  'ulaca',
#  'bentue',
#  'tunel',
#  'bernia',
#  'cabaces',
#  'moretona',
#  'salt de la bella dona',
#  'jurassic wall',
#  'roques de cosdevia',
#  'benasque',
#  'pinos',
#  'villanueva de valdegovia',
#  'marea',
#  'alos de balaguer',
#  'cacin',
#  'picu urriellu',
#  'echo valley',
#  'biar',
#  'montserrat',
#  'san martin de valdeiglesias',
#  'hermida',
#  'villanueva',
#  'zeus',
#  'cogollios',
#  'mogan',
#  'huesa',
#  'comarca',
#  'castillo de bayuela',
#  'santanyi',
#  'perxas',
#  'malpas',
#  'santa ana',
#  'agboli',
#  'reconco',
#  'amfiet murcia',
#  'murla',
#  'seguencu',
#  'soller',
#  'cenobio',
#  'san martin de valdonsera',
#  'gombren',
#  'rio chico',
#  'onil',
#  'santuari',
#  'jaen',
#  'olivella',
#  'solana',
#  'coves de larbert',
#  'risca',
#  'loja',
#  'mongrony',
#  'xert',
#  'tarifa',
#  'cervol',
#  'estrets',
#  'cuevaboyu',
#  'sstret',
#  'cala figuera',
#  'cala romatica',
#  'calella',
#  'galayos',
#  'granada',
#  'can jorba',
#  'pena del corb',
#  'malpas de travil',
#  'borda de arnaldet',
#  'cantera',
#  'st lloenc',
#  'mascarat gorge',
#  'arico viejo',
#  'arico nuevo',
#  'arico viejo',
#  'st llorenc',
#  'guayente',
#  'ampriu',
#  'mont sant',
#  'estrets del servol',
#  'pena maria',
#  'marazul',
#  'hoces',
#  'borda',
#  'bentue de rasal',
#  'lugo',
#  'pena el corb',
#  'pena roja xalo',
#  'vilanova i la geltru',
#  'sacs',
#  'ermita d arta',
#  'amposta',
#  'sant carles de la rapita',
#  'amieva',
#  'es burgaescorca',
#  'roca moura',
#  'santa coloma de farners',
#  'santa coloma de farners',
#  'tajo',
#  'clavijo',
#  'borda',
#  'congosto',
#  'camrasa',
#  'sta anna',
#  'bentue de rasal',
#  'norte',
#  'murla alcalali',
#  'qsuiros',
#  'squiros',
#  'valverdin',
#  'vlaverdin',
#  'borda',
#  'jarafuel',
#  'barranquet del ferry',
#  'andrebot',
#  'pequeno paraiso',
#  'glaciere',
#  'antepauta',
#  'alcalali',
#  'barranquet de ferri',
#  'faro',
#  'cabrera spain',
#  'pena pintada',
#  'latalaia vilanova',
#  'pena pintada',
#  'sta coloma farners',
#  'stacoloma farners',
#  'valdeprados',
#  'panocha',
#  'sta anna',
#  'cedrilles',
#  'gallinero',
#  'buda ibiza',
#  'roc de la lluna',
#  'rodeiro',
#  'estrets del cervol',
#  'mediona',
#  'penyes rojes',
#  'back itis',
#  'puerto roque',
#  's anna',
#  'ermita d arta',
#  'escondite',
#  'izquierda oeste',
#  'aguero',
#  'pont de larc',
#  'cala montgo',
#  'castelldefels',
#  'villanua',
#  'aljibes',
#  'sanna',
#  'suriana',
#  'pena de fresnidiello',
#  'cogullons',
#  'torrelletes',
#  'badum',
#  'huesa bermeja',
#  'huesa bermeja',
#  'hoya de pineda',
#  'raco tranquil',
#  'cala barques',
#  'restanca',
#  'els cogullons',
#  'gombrem',
#  'cabo negro',
#  'vilanova i la geltru',
#  'santamera',
#  'maretas',
#  'maretas',
#  'aljibes',
#  'llacuna',
#  'ermita darta',
#  'vegas',
#  'guadalest',
#  'tossal de la creu',
#  'pont de suert',
#  'barranco la fuente',
#  'biesla',
#  'arnao',
#  'premono',
#  'fo de la canal',
#  'valverdin pedrosa',
#  'regalito de reyes',
#  'cercedilla',
#  'hoces',
#  'perxas',
#  'salvatierra',
#  'urbasa',
#  'galilea korea',
#  'benasque',
#  'torrelletas',
#  'talaia',
#  'vva i la geltru',
#  'senarta',
#  'alkezar',
#  'st anna',
#  'foz de la canal',
#  'salto',
#  'fronton',
#  'fronton',
#  'sur del castillo',
#  'sur',
#  'canjorro',
#  'escudo',
#  'roc de la lluna',
#  'travesani',
#  'monte galineiro',
#  'bentue rasal',
#  'gorblau',
#  'soleia',
#  'snt llorenc',
#  'santa lucia',
#  'sorrueda',
#  'onati',
#  'es burga',
#  'penedos de oulego',
#  'cuebabollu',
#  'lugo',
#  'cuebabollu',
#  'cuevabollu',
#  'son txanquete',
#  'ermita d arta',
#  'font',
#  'can guies',
#  'es burgar',
#  'gor blau',
#  'es burgar',
#  'priorino',
#  'chanteiro',
#  'getariako bulderrak',
#  'es burga',
#  'es bulgar',
#  'penas pintadas',
#  'berberana',
#  'huesa bermeja',
#  'cuba',
#  'arucas',
#  'chira',
#  'cenovio',
#  'gravera',
#  'sigues',
#  'recuevas gama',
#  'pancorvo',
#  'esportives dhorto',
#  'liguerre',
#  'lagos motril granada',
#  'monte ferro',
#  'ampriu',
#  'r dels capellans',
#  'r de capellans',
#  'r de capellans',
#  'l ocaive',
#  'peton del xalo',
#  'chanteiro',
#  'prior',
#  'castell de les dames',
#  'guayente',
#  'remune',
#  'caldas de luna',
#  'cavallers',
#  'cavalles',
#  'mella',
#  'lhermita darta',
#  'san lorenzo del monte',
#  'morcin',
#  'perxitas',
#  'viana de jadraque',
#  'penalara',
#  'castell de les dames',
#  'perxas',
#  'font',
#  'gorg glau',
#  'son xanquete',
#  'torrent dels porxos',
#  'sermita darta',
#  'es burgar',
#  'lermita arta',
#  'costa blanca',
#  'santuari',
#  'bentue de rasal',
#  'titolos',
#  'font ametllo',
#  'st joan de mediona',
#  'creu de codo',
#  'buste',
#  'garraf barcelona',
#  'alrededores de barna',
#  'alrededores de barcelona',
#  'salmon',
#  'cerulleda',
#  'muro sepu',
#  'muro sepu',
#  'muela',
#  'naranjo de bulnes',
#  'fuixarda',
#  'penata broto',
#  'aviados',
#  'st ana',
#  'alcaudete de la jara',
#  'santa lucia',
#  'spain',
#  'pic del martell',
#  'montrebei',
#  'mont roig',
#  'cilindre',
#  'toix calpe',
#  'roda de ter',
#  'bruce lee buttress',
#  'cala moraig',
#  'latalaia',
#  'lavella',
#  'collsuspina',
#  'coll de la barraca',
#  'can figuera',
#  'gelida',
#  'moia',
#  'olesa',
#  'horta de sjuan',
#  'horta de s juan',
#  'santuari del lord',
#  'silla felipe ii',
#  'valverdin pedrosa',
#  'aviados',
#  'naranjito',
#  'canada',
#  '',
#  'ponts',
#  'navahermosa',
#  'teverga',
#  'cumbre',
#  'perxces',
#  'echo',
#  'badajoz',
#  'alange',
#  'orzola',
#  'jameo de la puerta falsa',
#  'aiguespases',
#  'ulldecona',
#  'tozal',
#  'montaguserrat',
#  'resconorio',
#  'barrancazo',
#  'pequena escocia',
#  'jaraba',
#  'martxuquera',
#  'cerro del hierro',
#  'figueiras',
#  'barrancazo',
#  'castillo de alaro',
#  'san sebastian tutla',
#  'pedrena',
#  'sorrueda',
#  'regero',
#  'veriel',
#  'verriel',
#  'cenovio',
#  'chira',
#  'ayacata',
#  'cevera',
#  'boalo',
#  'moixent',
#  'roc de la lluna',
#  'barruecos',
#  'tagamanent',
#  'monserrat can jorva',
#  'mercadal superior',
#  'bentue de rasal',
#  'toralba de los frailes',
#  'mallorca cala barques',
#  'lagos',
#  'rapita',
#  'tallat roig',
#  'tramacastilla',
#  'cacin',
#  'cabrils',
#  'calpe',
#  'turtzioz',
#  'potrt de soller',
#  'manilva',
#  'cueva de otinar',
#  'canjorro',
#  'barranco fuerte',
#  'torre den beau',
#  'torre den beau',
#  'caos de villanueva del rosario',
#  'tajo del abanico',
#  'castell santueri',
#  'cuenco',
#  's avenc',
#  'castell de les dames',
#  'cales varques',
#  'santorens',
#  'os balaguer',
#  'castellet',
#  'pedrafroca',
#  'molinucos',
#  'esporlas es verger',
#  'embid',
#  'pas de la mala dona',
#  'eume',
#  'vva de prades',
#  'vica',
#  'vic',
#  'sabassona',
#  'fuerteventura',
#  'cementeriocallosa del segura',
#  'sorrueda',
#  'pena corneira',
#  'maretas',
#  'regalito de reyes',
#  'covatelles',
#  'aventador',
#  'locaive',
#  'vallecito',
#  'vies raid lord',
#  'montseny',
#  'monsterrat',
#  'revisa',
#  'llosa del cavall',
#  'stoney ridge',
#  'sermita darta',
#  'roca de misa',
#  'moya',
#  'zumaia getaria',
#  'zumaia getaria',
#  'gorge blau',
#  'regeiro',
#  'mataelpino',
#  'barcelona',
#  'portillas',
#  'huesa',
#  'clot de lespasa',
#  'gerro',
#  'montbru',
#  'sector central',
#  'cervera',
#  'monjas',
#  'ason',
#  'berrueco',
#  'ahedo',
#  'ahedo',
#  'pena maria',
#  'cruz velilla',
#  'pont de camps',
#  'pont de camps',
#  'ayagaures',
#  'mont roig',
#  'cala sa nau',
#  'son xanki',
#  'lermita',
#  'corones',
#  'gandiia',
#  'a',
#  'c',
#  'b',
#  'menut',
#  'yermo',
#  'bunyol',
#  'museo',
#  'clot de lespasa',
#  'coronas',
#  'roca blanca',
#  'ricote',
#  'tamadaba',
#  'vilanova i la g',
#  'parra',
#  'zumaia getaria',
#  'temisa',
#  'cueva de orsola',
#  'guatisa',
#  'allbaraccin',
#  'sorueda',
#  'ceovio',
#  'pena corneira',
#  'bayuela',
#  'hacha',
#  'uceda',
#  'monte galineiro',
#  'atalaya',
#  'buendia',
#  'torralba',
#  'tajos del canjorro',
#  'cocentaina',
#  'saleretes',
#  'martianez',
#  'rodeiro',
#  'esteiro',
#  'elche',
#  'les saletes',
#  'les saletes',
#  'bobedon',
#  'barranco de la hoz',
#  'chopos',
#  'bobedon',
#  'bobedon',
#  'marxuquera',
#  'marxuquera',
#  'ledesma',
#  'sabassona',
#  'nerja playa',
#  'valec',
#  'gran canaria',
#  'cenobio',
#  'mont sant',
#  'samta gadea',
#  'alcandoras',
#  'matrix',
#  'savenc',
#  'els sumiders',
#  'salta linya',
#  'cheste',
#  'itoiz',
#  'itoiiz',
#  'cuenco',
#  'cala san vicents',
#  'caudete',
#  'rincon de bonanza',
#  'camporredondo',
#  'corme costa da morte',
#  'traba costa da morte',
#  'paseo nuevo',
#  'betlem',
#  'malanyeu',
#  'caldas',
#  'tajos de las alcandoras',
#  'estres del cervol',
#  'boquer',
#  'barruecos',
#  'esparragalejo',
#  'c priorino',
#  'llosa del caval',
#  'segad',
#  'aange',
#  'espiel',
#  'naalosa',
#  'sorueda gran canarias',
#  'cara sur del castillo',
#  'urbasa',
#  'ponton de la oliva',
#  'pont de suert',
#  'echo playa',
#  'tropical dreams',
#  'callosa',
#  'belmez',
#  'bellavista',
#  'ocaive',
#  'salamanca',
#  'jameo puerta falsa',
#  'caldas de reis',
#  'montrfrio',
#  'althea',
#  'pena roya',
#  'costa blanca',
#  'fumat',
#  'santana',
#  'meano',
#  'matxuquera',
#  'ermita arta',
#  'gran canaria',
#  'foixarda',
#  'penja roga',
#  'arabe',
#  'valledemossa',
#  'plaques deco',
#  'santjani mallorca',
#  'cara sur del castillo',
#  'escales soperia',
#  'displomandia',
#  'can ximet',
#  'locaive',
#  'sarratella',
#  'bruises',
#  'castell espassa',
#  'ripolles',
#  'borriol',
#  'torcal',
#  'les esposes',
#  'jameos',
#  'fra',
#  'coll de la barraca',
#  'zona x',
#  'plas mala dona',
#  'moratona',
#  'cova mongai',
#  'vilanova',
#  'boquer',
#  'ripoll',
#  'monterrat',
#  'poza de la mona',
#  'como la vida misma',
#  'siruana',
#  'l pedriza',
#  'lezaia',
#  'paseo nuevo donosti',
#  'benaojan',
#  'boda',
#  'vilinova',
#  'a',
#  'aa',
#  'entrpenas',
#  'orihuelade re',
#  'maxuquera',
#  'chopos',
#  'cuevabollu',
#  'paseo nuevo',
#  'paseo nuevo',
#  'patiras',
#  'paseo nuevo donosti',
#  'paseo nuevo',
#  'toix seacliffs',
#  'mortitx',
#  'ager',
#  'thalaia',
#  'riba',
#  'cogollons',
#  'calders',
#  'colmenas',
#  'canarias',
#  'canrias',
#  'barranco de los naranjos',
#  'montsec',
#  'suiurana',
#  'montrgony',
#  'montsia',
#  '',
#  'estrets del selvol',
#  'cingles',
#  'regalito de reyes',
#  'regalito',
#  'canboquet',
#  'caldas',
#  'font',
#  'faro hondarribia',
#  'villena',
#  'corro',
#  'gandesa',
#  'berzosa',
#  'felechosa',
#  'ppintada',
#  'penas rojas',
#  'matalpino',
#  'vall de ribes',
#  'orgiva',
#  'penoncillos lanjaron',
#  'montmell',
#  'san martin de valiglesias',
#  'chopos',
#  'chopos',
#  'san miguel',
#  ...]

# %% [markdown]
# ## · Similarity

# %% [markdown]
# If they are included into each other

# %%
def included(a,b):
    # If the word is included in a phrase
    a = " " + a + " "
    b = " " + b + " "
    if (a in b) or (b in a):
        return True
    return False

# %%
included("hola", "hola mundo")
# Out:
# True

# %% [markdown]
# If they look similar

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b, autojunk=True).ratio()

# %%
similar('hola','olo')
# Out:
# 0.5714285714285714

# %% [markdown]
# Replace by the most frequent

# %%
def replace_frequent(a,b,ls):
    '''
    Compare the ocurrences of each string of a list and 
    then returns a list with the strings replaced by the most frequent value
    '''
    if ls.count(a) > ls.count(b):
        return [a if (s == b) else s for s in ls ]
    else:
        return [b if (s == a) else s for s in ls ]

# %%
ls = ['a1','a2','a3','b', 'c', 'a', 'd', 'b', 'c', 'd', 'c', 'a', 'b','a','a1','a2','a','b']

# %%
ls_rep = replace_frequent('a1','b',ls)
ls_rep
# Out:
# ['b',
#  'a2',
#  'a3',
#  'b',
#  'c',
#  'a',
#  'd',
#  'b',
#  'c',
#  'd',
#  'c',
#  'a',
#  'b',
#  'a',
#  'b',
#  'a2',
#  'a',
#  'b']

# %% [markdown]
# Put all together

# %%
def Replace_similar_array(arr, similarity = 0.9, similarity_ask = 1, show = False):
    '''
    This functions compares every string of a list with each other and replaces if they are similar.
    It keeps the most frequent value and replaces the occurences of the other one

    input:
    arr -> np.array with the strings we want to compare
    similarity -> the similarity threshold, automatically does the correction
    similarity_ask -> this threshold asks the user if the text is similar or not before correcting
    show -> True for a results viewer

    output:
    The np.array with the similar values replaced
    '''

    str_arr = arr.copy()
    

    for index1 in range(len(str_arr)):
        for index2 in range(index1 + 1,len(str_arr)):
                            
            name1 = str_arr[index1]
            name2 = str_arr[index2] 
                            
                            
            if name1 != name2:
                inc = included(name1,name2)

                if inc:
                    str_arr = replace_frequent(name1,name2,str_arr)

                else:               
                    sim = similar(name1,name2)

                    if (sim > similarity) & (sim != 1):

                        if (show == True):
                            print("Replacing all the values with",name2,"by", name1,". Similarity: ",sim)
                        str_arr = replace_frequent(name1,name2,str_arr) 

                    elif (sim > similarity_ask) & (sim != 1):

                        print('Are they the same? (n if not) -> ', name1, " <<>> ",name2, " (", sim, ")")
                        x = input()

                        if x != 'n':
                            str_arr = replace_frequent(name1,name2,str_arr)
                            print("Replacing all the values with",name2,"by", name1,". Similarity: ",sim)


    return str_arr

# %%
# %%time
crag_sim = Replace_similar_array(arr = crag_punct, 
              similarity = 0.85, # playing a little with this similarity values found that .8 is a good value
              similarity_ask = 1,              
              show = True)
# Out:
# Replacing all the values with larboli by arboli . Similarity:  0.9230769230769231
# Replacing all the values with arbolii by arboli . Similarity:  0.9230769230769231
# Replacing all the values with aboli by arboli . Similarity:  0.9090909090909091
# Replacing all the values with arboi by arboli . Similarity:  0.9090909090909091
# Replacing all the values with arbolli by arboli . Similarity:  0.9230769230769231
# Replacing all the values with mont sant by montsant . Similarity:  0.9411764705882353
# Replacing all the values with mon sant by mont sant . Similarity:  0.9411764705882353
# Replacing all the values with monsant by mont sant . Similarity:  0.875
# Replacing all the values with motsant by mont sant . Similarity:  0.875
# Replacing all the values with suriana by siurana . Similarity:  0.8571428571428571
# Replacing all the values with siruana by siurana . Similarity:  0.8571428571428571
# Replacing all the values with suiurana by siurana . Similarity:  0.9333333333333333
# Replacing all the values with ciurana by siurana . Similarity:  0.8571428571428571
# Replacing all the values with suirana by siurana . Similarity:  0.8571428571428571
# Replacing all the values with surana by siurana . Similarity:  0.9230769230769231
# Replacing all the values with siuarana by siurana . Similarity:  0.9333333333333333
# Replacing all the values with siuranas by siurana . Similarity:  0.9333333333333333
# Replacing all the values with syurana by siurana . Similarity:  0.8571428571428571
# Replacing all the values with siurna by siurana . Similarity:  0.9230769230769231
# Replacing all the values with siiurana by siurana . Similarity:  0.9333333333333333
# Replacing all the values with siurnana by siurana . Similarity:  0.9333333333333333
# Replacing all the values with zl chorro by el chorro . Similarity:  0.8888888888888888
# Replacing all the values with el chorrro by el chorro . Similarity:  0.9473684210526315
# Replacing all the values with el corro by el chorro . Similarity:  0.9411764705882353
# Replacing all the values with port soller by port de soller . Similarity:  0.88
# Replacing all the values with potrt de soller by port de soller . Similarity:  0.9655172413793104
# Replacing all the values with puerto de soller by port de soller . Similarity:  0.8666666666666667
# Replacing all the values with por de soller by port de soller . Similarity:  0.9629629629629629
# Replacing all the values with mallora cala barques by mallorca cala barques . Similarity:  0.975609756097561
# Replacing all the values with jrica by jerica . Similarity:  0.9090909090909091
# Replacing all the values with cueca by cuenca . Similarity:  0.9090909090909091
# Replacing all the values with baaltzola by baltzola . Similarity:  0.9411764705882353
# Replacing all the values with blatzola by baltzola . Similarity:  0.875
# Replacing all the values with balzola by baltzola . Similarity:  0.9333333333333333
# Replacing all the values with batzola by baltzola . Similarity:  0.9333333333333333
# Replacing all the values with baltzla by baltzola . Similarity:  0.9333333333333333
# Replacing all the values with seilla by sella . Similarity:  0.9090909090909091
# Replacing all the values with sellia by sella . Similarity:  0.9090909090909091
# Replacing all the values with sela by sella . Similarity:  0.8888888888888888
# Replacing all the values with cabeso de oro by cabezon de oro . Similarity:  0.8888888888888888
# Replacing all the values with cabezon dor by cabezon de oro . Similarity:  0.88
# Replacing all the values with cabezon de orro by cabezon de oro . Similarity:  0.9655172413793104
# Replacing all the values with appelaniz by apellaniz . Similarity:  0.8888888888888888
# Replacing all the values with mongrony by montgrony . Similarity:  0.9411764705882353
# Replacing all the values with montrgony by montgrony . Similarity:  0.8888888888888888
# Replacing all the values with montrgrony by montgrony . Similarity:  0.9473684210526315
# Replacing all the values with exauri by etxauri . Similarity:  0.9230769230769231
# Replacing all the values with extauri by etxauri . Similarity:  0.8571428571428571
# Replacing all the values with eguino by egino . Similarity:  0.9090909090909091
# Replacing all the values with ptones by patones . Similarity:  0.9230769230769231
# Replacing all the values with platones by patones . Similarity:  0.9333333333333333
# Replacing all the values with roddelar by rodellar . Similarity:  0.875
# Replacing all the values with rdellar by rodellar . Similarity:  0.9333333333333333
# Replacing all the values with radellar by rodellar . Similarity:  0.875
# Replacing all the values with rondellar by rodellar . Similarity:  0.9411764705882353
# Replacing all the values with rodelard by rodellar . Similarity:  0.875
# Replacing all the values with rodellard by rodellar . Similarity:  0.9411764705882353
# Replacing all the values with carla magraner by cala magraner . Similarity:  0.9629629629629629
# Replacing all the values with trerradets by terradets . Similarity:  0.9473684210526315
# Replacing all the values with terradest by terradets . Similarity:  0.8888888888888888
# Replacing all the values with tarradets by terradets . Similarity:  0.8888888888888888
# Replacing all the values with salina by salinas . Similarity:  0.9230769230769231
# Replacing all the values with salinass by salinas . Similarity:  0.9333333333333333
# Replacing all the values with gandiia by gandia . Similarity:  0.9230769230769231
# Replacing all the values with ghandia by gandia . Similarity:  0.9230769230769231
# Replacing all the values with ganda by gandia . Similarity:  0.9090909090909091
# Replacing all the values with vva i la geltru by vilanova i la geltru . Similarity:  0.8571428571428571
# Replacing all the values with vilanova i la g by vilanova i la geltru . Similarity:  0.8571428571428571
# Replacing all the values with vilanova y geltru by vilanova i la geltru . Similarity:  0.8648648648648649
# Replacing all the values with vilanova y la geltru by vilanova i la geltru . Similarity:  0.95
# Replacing all the values with ola by olta . Similarity:  0.8571428571428571
# Replacing all the values with serra de toix by sierra de toix . Similarity:  0.9629629629629629
# Replacing all the values with la forcada by la forada . Similarity:  0.9473684210526315
# Replacing all the values with el esorial by el escorial . Similarity:  0.9523809523809523
# Replacing all the values with es escorial by el escorial . Similarity:  0.9090909090909091
# Replacing all the values with elescorial by el escorial . Similarity:  0.9523809523809523
# Replacing all the values with el esocrial by el escorial . Similarity:  0.9090909090909091
# Replacing all the values with l pedriza by la pedriza . Similarity:  0.9473684210526315
# Replacing all the values with le pedriza by la pedriza . Similarity:  0.9
# Replacing all the values with lapedriza by la pedriza . Similarity:  0.9473684210526315
# Replacing all the values with la perdiza by la pedriza . Similarity:  0.9
# Replacing all the values with la pediza by la pedriza . Similarity:  0.9473684210526315
# Replacing all the values with la periza by la pedriza . Similarity:  0.9473684210526315
# Replacing all the values with la pedriz by la pedriza . Similarity:  0.9473684210526315
# Replacing all the values with la prediza by la pedriza . Similarity:  0.9
# Replacing all the values with el pedriza by la pedriza . Similarity:  0.9
# Replacing all the values with la pedri by la pedriza . Similarity:  0.8888888888888888
# Replacing all the values with la perdriza by la pedriza . Similarity:  0.9523809523809523
# Replacing all the values with montaguserrat by montserrat . Similarity:  0.8695652173913043
# Replacing all the values with monsterrat by montserrat . Similarity:  0.9
# Replacing all the values with monterrat by montserrat . Similarity:  0.9473684210526315
# Replacing all the values with monserat by montserrat . Similarity:  0.8888888888888888
# Replacing all the values with montsrrat by montserrat . Similarity:  0.9473684210526315
# Replacing all the values with monserrat by montserrat . Similarity:  0.9473684210526315
# Replacing all the values with motserrat by montserrat . Similarity:  0.9473684210526315
# Replacing all the values with monsetserrat by montserrat . Similarity:  0.9090909090909091
# Replacing all the values with montserrart by montserrat . Similarity:  0.9523809523809523
# Replacing all the values with mont serrat by montserrat . Similarity:  0.9523809523809523
# Replacing all the values with maontserrat by montserrat . Similarity:  0.9523809523809523
# Replacing all the values with montsserrat by montserrat . Similarity:  0.9523809523809523
# Replacing all the values with el torcalito by el torcal . Similarity:  0.8571428571428571
# Replacing all the values with el trocal by el torcal . Similarity:  0.8888888888888888
# Replacing all the values with lariba by la riba . Similarity:  0.9230769230769231
# Replacing all the values with la rib by la riba . Similarity:  0.9230769230769231
# Replacing all the values with la arriba by la riba . Similarity:  0.875
# Replacing all the values with sadernas by sadernes . Similarity:  0.875
# Replacing all the values with sadenas by sadernas . Similarity:  0.9333333333333333
# Replacing all the values with arotz by araotz . Similarity:  0.9090909090909091
# Replacing all the values with arahotz by araotz . Similarity:  0.9230769230769231
# Replacing all the values with rafales by ramales . Similarity:  0.8571428571428571
# Replacing all the values with el covento by el convento . Similarity:  0.9523809523809523
# Replacing all the values with t verga by teverga . Similarity:  0.8571428571428571
# Replacing all the values with te ver ga by teverga . Similarity:  0.875
# Replacing all the values with desplomelandia by desplomilandia . Similarity:  0.9285714285714286
# Replacing all the values with desplomilanda by desplomilandia . Similarity:  0.9629629629629629
# Replacing all the values with deplomilandia by desplomilandia . Similarity:  0.9629629629629629
# Replacing all the values with displomilandia by desplomilandia . Similarity:  0.9285714285714286
# Replacing all the values with arco by arico . Similarity:  0.8888888888888888
# Replacing all the values with cala santani by cala santanyi . Similarity:  0.96
# Replacing all the values with cala santany by cala santanyi . Similarity:  0.96
# Replacing all the values with estrets by sestret . Similarity:  0.8571428571428571
# Replacing all the values with sstret by sestret . Similarity:  0.9230769230769231
# Replacing all the values with s estret by sestret . Similarity:  0.9333333333333333
# Replacing all the values with sesrtet by sestret . Similarity:  0.8571428571428571
# Replacing all the values with ses tret by sestret . Similarity:  0.9333333333333333
# Replacing all the values with setret by sestret . Similarity:  0.9230769230769231
# Replacing all the values with estret by sestret . Similarity:  0.9230769230769231
# Replacing all the values with estreet by sestret . Similarity:  0.8571428571428571
# Replacing all the values with seestret by sestret . Similarity:  0.9333333333333333
# Replacing all the values with sant llorenc del munt by sant llorenc de montgai . Similarity:  0.8636363636363636
# Replacing all the values with sa gubiant llorenc de munt by sant llorenc del munt . Similarity:  0.851063829787234
# Replacing all the values with sant lloreny del munt by sant llorenc del munt . Similarity:  0.9523809523809523
# Replacing all the values with stllorenc del m unt by sant llorenc del munt . Similarity:  0.9
# Replacing all the values with san llorent de munt by sant llorenc del munt . Similarity:  0.9
# Replacing all the values with st lorenc del munt by sant llorenc del munt . Similarity:  0.9230769230769231
# Replacing all the values with st llorenc del munt by sant llorenc del munt . Similarity:  0.95
# Replacing all the values with sant llorenc de morunys by sant llorenc del munt . Similarity:  0.8636363636363636
# Replacing all the values with sant llorent del munt by sant llorenc del munt . Similarity:  0.9523809523809523
# Replacing all the values with santt llorenc del munt by sant llorenc del munt . Similarity:  0.9767441860465116
# Replacing all the values with st llorens del munt by sant llorenc del munt . Similarity:  0.9
# Replacing all the values with sant llorens del munt by sant llorenc del munt . Similarity:  0.9523809523809523
# Replacing all the values with sant llorenc de munt by sant llorenc del munt . Similarity:  0.975609756097561
# Replacing all the values with st llorenc del munc by sant llorenc del munt . Similarity:  0.9
# Replacing all the values with sant lloren del munt by sant llorenc del munt . Similarity:  0.975609756097561
# Replacing all the values with sant llorenc del mun by sant llorenc del munt . Similarity:  0.975609756097561
# Replacing all the values with camrasa by camarasa . Similarity:  0.9333333333333333
# Replacing all the values with camasa by camarasa . Similarity:  0.8571428571428571
# Replacing all the values with camarrasa by camarasa . Similarity:  0.9411764705882353
# Replacing all the values with camarassa by camarasa . Similarity:  0.9411764705882353
# Replacing all the values with sagubia by sa gubia . Similarity:  0.9333333333333333
# Replacing all the values with sa gabia by sa gubia . Similarity:  0.875
# Replacing all the values with valdegovia by valdegobia . Similarity:  0.9
# Replacing all the values with valdegavia by valdegovia . Similarity:  0.9
# Replacing all the values with vakdegovia by valdegovia . Similarity:  0.9
# Replacing all the values with valedegobia by valdegovia . Similarity:  0.8571428571428571
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-32-2144d3ff5364> in Replace_similar_array(arr, similarity, similarity_ask, show)
#      31
#      32                 else:
# ---> 33                     sim = similar(name1,name2)
#      34
#      35                     if (sim > similarity) & (sim != 1):
#
# <ipython-input-27-9e241f802b49> in similar(a, b)
#       1 def similar(a, b):
# ----> 2     return SequenceMatcher(None, a, b, autojunk=True).ratio()
#
# /usr/lib/python3.9/difflib.py in ratio(self)
#     649         """
#     650
# --> 651         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     652         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     653
#
# /usr/lib/python3.9/difflib.py in get_matching_blocks(self)
#     484         while queue:
#     485             alo, ahi, blo, bhi = queue.pop()
# --> 486             i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     487             # a[alo:i] vs b[blo:j] unknown
#     488             # a[i:i+k] same as b[j:j+k]
#
# /usr/lib/python3.9/difflib.py in find_longest_match(self, alo, ahi, blo, bhi)
#     415                 if j >= bhi:
#     416                     break
# --> 417                 k = newj2len[j] = j2lenget(j-1, 0) + 1
#     418                 if k > bestsize:
#     419                     besti, bestj, bestsize = i-k+1, j-k+1, k
#
# KeyboardInterrupt:

# %% [markdown]
# Thi process is quite slow, we want to make it <b> faster </b>
#
# Replacements table: We are going to create a <b>table</b> of replacements and then replace from it the original list

# %%
def replace_frequent_uniq(a,b,uniq_ls,orig_ls):
    
    freq = a if (orig_ls.count(a) > orig_ls.count(b)) else b
   
    if freq == a:
        return [a if (s == b) else s for s in uniq_ls ]
    else:
        return [b if (s == a) else s for s in uniq_ls ]

# %%
uniq_ls = pd.array(ls).unique()
ls_rep = replace_frequent_uniq('a','b',list(uniq_ls),ls)

# %%
rep_table = pd.DataFrame({'original':uniq_ls,'most_freq':ls_rep})
rep_table
# Out:
#   original most_freq
# 0       a1        a1
# 1       a2        a2
# 2       a3        a3
# 3        b         b
# 4        c         c
# 5        a         b
# 6        d         d

# %%
[rep_table[rep_table.original == value].most_freq.values[0] for value in ls]
# Out:
# ['a1',
#  'a2',
#  'a3',
#  'b',
#  'c',
#  'b',
#  'd',
#  'b',
#  'c',
#  'd',
#  'c',
#  'b',
#  'b',
#  'b',
#  'a1',
#  'a2',
#  'b',
#  'b']

# %%
def replace_frequent_with_table(orig_ls,similarity = 0.85, similarity_ask = 1, show = False):
    '''
    This method is replacing the similar values of a list by the most frequent one.
    In this approach first we calculate the unique values and then we make the replacement table.
    Finally we search for the replacements of the list on this table saving us time (exponentially)
    
    input:
    orig_ls -> the list
    show -> if true it shows all the logs
    
    output:
    it returns the list
    
    '''
    arr_original = orig_ls.copy()
    
    arr_uniq = pd.array(arr_original).unique()
    
    arr_uniq_copy = arr_uniq.copy()

    for index1 in range(len(arr_uniq)):
        for index2 in range(index1 + 1,len(arr_uniq)):
                            
            name1 = arr_uniq_copy[index1]
            name2 = arr_uniq_copy[index2] 
                            
                            
            if name1 != name2:
                inc = included(name1,name2)

                if inc:
                    arr_uniq_copy = replace_frequent_uniq(name1, name2, arr_uniq_copy, arr_original)

                else:               
                    sim = similar(name1,name2)

                    if (sim > similarity) & (sim != 1):

                        if (show == True):
                            print("Replacing all the values with",name2,"by", name1,". Similarity: ",sim)
                        arr_uniq_copy = replace_frequent_uniq(name1,name2,arr_uniq_copy,arr_original) 

                    elif (sim > similarity_ask) & (sim != 1):

                        print('Are they the same? (n if not) -> ', name1, " <<>> ",name2, " (", sim, ")")
                        x = input()

                        if x != 'n':
                            arr_uniq_copy = replace_frequent_uniq(name1, name2, arr_uniq_copy, arr_original)
                            print("Replacing all the values with",name2,"by", name1,". Similarity: ",sim)
                            
                            
    
    # We create the table
    rep_table = pd.DataFrame({'original':arr_uniq,'most_freq':arr_uniq_copy})
    
    if show:
        display(rep_table)
    
    ls_orig_rep = [rep_table[rep_table.original == value].most_freq.values[0] for value in orig_ls]
    
    return ls_orig_rep

# %%
ls = ['a1','a2','a3','b', 'c1', 'a', 'd', 'b1', 'c', 'd', 'c', 'a1', 'b','a','a1','a2','a','b1',
     'a1','a2','a3','b', 'c2', 'a', 'd', 'b2', 'c', 'd', 'c', 'a2', 'b','a','a1','a2','a','b',
     'a1','a2','a3','b', 'c3', 'a', 'd', 'b1', 'c', 'd', 'c', 'a1', 'b','a','a1','a2','a','b2']

# %%
ans = replace_frequent_with_table(ls,similarity = 0.5, show = True)
# Out:
# Replacing all the values with a by a1 . Similarity:  0.6666666666666666
# Replacing all the values with a by a2 . Similarity:  0.6666666666666666
# Replacing all the values with a by a3 . Similarity:  0.6666666666666666
# Replacing all the values with b1 by b . Similarity:  0.6666666666666666
# Replacing all the values with b2 by b . Similarity:  0.6666666666666666
# Replacing all the values with c by c1 . Similarity:  0.6666666666666666
# Replacing all the values with c2 by c . Similarity:  0.6666666666666666
# Replacing all the values with c3 by c . Similarity:  0.6666666666666666
#    original most_freq
# 0        a1         a
# 1        a2         a
# 2        a3         a
# 3         b         b
# 4        c1         c
# 5         a         a
# 6         d         d
# 7        b1         b
# 8         c         c
# 9        c2         c
# 10       b2         b
# 11       c3         c

# %% [markdown]
# Lets see how fast it is:

# %%
# %%time
crag_sim = replace_frequent_with_table(orig_ls = crag_punct,
                                       show = False)
# Out:
# CPU times: user 6min 53s, sys: 160 ms, total: 6min 53s
# Wall time: 6min 53s

# %% [markdown]
# #### ...we see that we saved a lot of time with this table method

# %%
myset5 = set(crag_sim)
len(myset5)
# Out:
# 3542

# %%
pd.Series(crag_sim).value_counts().head(10)
# Out:
# sant llorenc del munt    33
# a                        33
# siurana                  31
# st llorenc de montgai    31
#                          29
# sestret                  29
# la pedriza               28
# albarracin               25
# margalef                 24
# chulilla                 23
# dtype: int64

# %% [markdown]
# A big improvement respect the original:

# %%
pd.Series(crags).value_counts().head(10)
# Out:
# Arboli              1
# merola              1
# Petonn do Xalo      1
# Port d'escanonge    1
# crevillent          1
# Cinfuens            1
# Oncins              1
# Priego              1
# El pedriza          1
# Cabeço gordo        1
# dtype: int64

# %% [markdown]
# We now put everything inside the text_processor class

# %%
crag_sim = txt.replace_frequent_with_table(arr = sorted(myset5))
myset6 = set(crag_sim)
len(myset6)

# %% [markdown]
# ## · Language check

# %%
from polyglot.detect import Detector
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sentiment_analysis_spanish import sentiment_analysis

# %%
mixed_text = "La via es muy buena"
det = Detector(mixed_text, quiet=True)
print(det.language)
# Out:
# name: Spanish     code: es       confidence:  95.0 read bytes:  1280

# %%
def Language_check(mixed_text, lang_check = 'en'):
    '''
    This function checks if the language of the text is the expected

    inputs:
    - mixef_text => text to analyze
    - lang_check => the language we want to validate

    output:
    boolean, true or false
    '''



    det = Detector(mixed_text, quiet=True)
    lang = det.languages[0].code
    conf = det.languages[0].confidence

    if (lang == lang_check) and (conf > 0.5):
        return True

    return False

# %%
Language_check("That was a good route",'en')
# Out:
# True

# %% [markdown]
# Now we use the class text_processor

# %%
txt.Language_check("La via es buenisima, y lo demas tambien",'es')
# Out:
# True

# %% [markdown]
# ## · Sentiment

# %% [markdown]
# This function will messure the sentiment of a comment

# %%
analyzer_en = SentimentIntensityAnalyzer()
analyzer_es = sentiment_analysis.SentimentAnalysisSpanish()
# Out:
# /home/jzar/.local/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator CountVectorizer from version 0.23.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/jzar/.local/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.23.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
analyzer_en.polarity_scores("Best climb of my life")
# Out:
# {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.6369}

# %%
analyzer_es.sentiment("Una escalada muy mala")
# Out:
# 0.0004283214610584631

# %%
# English
def English_sentiment(sentence, analyzer_en, show = False):
    '''
    This function analyzes a sentence in english to see if it is possitive or negative

    inputs:
    - sentence => text to analyze
    - show => if its True then it will show the results 

    output:
    returns a float between +-1 whith the result 
    '''   


    vs = analyzer_en.polarity_scores(sentence)
    if (vs['compound'] != 0) and show:
        print( '----------------------------------------------' )
        print(sentence)
        print(vs['compound'])

    return vs['compound']

#Spanish
def Spanish_sentiment(sentence, analyzer_es, show = False):
    '''
    This function analyzes a sentence in spanish to see if it is possitive or negative

    inputs:
    - sentence => text to analyze
    - show => if its True then it will show the results 

    output:
    returns a float between +-1 whith the result 
    '''   

    vs = analyzer_es.sentiment(sentence)*2-1
    if (vs != 0) and show:
        print( '----------------------------------------------' )
        print(sentence)
        print(vs)

    return vs

# %%
English_sentiment("Good route", analyzer_en, show = True)
# Out:
# ----------------------------------------------
# Good route
# 0.4404
# 0.4404

# %%
Spanish_sentiment("La via una maravilla", analyzer_es, show = True)
# Out:
# ----------------------------------------------
# La via una maravilla
# 0.9938294856508776
# 0.9938294856508776

# %% [markdown]
# ### Language check + Sentiment

# %%
def comment_sentiment(comment, analyzer_en, analyzer_es, show = False):
    '''
    This functions takes a comment, checks the language and if its english it checks the sentiment
    input:
    - comment -> text to analyze
    - show -> if you want to show results
    
    output:
    sentiment is a value between +-1
    ''' 
    
    try:
        # Check if its in english
        is_english = Language_check(comment)

        if is_english:
            # Check the sentiment
            return Sentiment_analyzer(comment, analyzer_en, show)

        # Works for both
        is_spanish = Language_check(comment,'es')
        is_italian = Language_check(comment,'it')

        if is_spanish or is_italian:
            # Check the sentiment
            return Spanish_sentiment(comment, analyzer_es, show)            

        return 0
        
    except:
        return 0

# %%
comment_sentiment("Good route, guys", analyzer_en, analyzer_es, show = True)
# Out:
# 0

# %%
comment_sentiment("La via una maravilla y lo demas", analyzer_en, analyzer_es, show = True)
# Out:
# ----------------------------------------------
# La via una maravilla y lo demas
# 0.989722003917165
# 0.989722003917165

# %% [markdown]
# Now we place it into the <b>class</b> in order to be able to use it in the future

# %%
txt.Language_check("Good route, guys, it was amazing")
# Out:
# True

# %%
txt.English_sentiment("Good route, guys, it was amazing")
# Out:
# 0.7717

# %%
txt.comment_sentiment("Good route, guys, it was amazing", show = True)
# Out:
# ----------------------------------------------
# Good route, guys, it was amazing
# 0.7717
# 0.7717

# %%
txt.comment_sentiment("La via una maravilla y lo demas", show = True)
# Out:
# ----------------------------------------------
# La via una maravilla y lo demas
# 0.989722003917165
# 0.989722003917165
