# %%
import pandas as pd
import numpy as np
from plot_jzar import *
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
pd.set_option("display.max_columns",None)
pd.set_option('display.max_rows', 10)

# %% [markdown]
# ### We have 3 types of data:
#
# - Independent features (clustered)
# - `How good the route is (the higher the better)` => <b>In this notebook we will work on this one
# - Grade, Location, sex, heigh (defined by user)

# %% [markdown]
# # Routes rating

# %% [markdown]
# Objective
# - We want to convert all the "rating" columns into a single one

# %%
routes = pd.read_csv('../data/routes_clustered.csv',low_memory=False, index_col=0)
print(routes.shape)
routes.tail(3)
# Out:
# (55087, 15)
#        name_id country            crag           sector            name  \
# 55084    55084     zaf     van stadens        the beach  out of control
# 55085    55085     zaf     van stadens        the beach      sheathless
# 55086    55086     zaf  waterval boven  baboon buttress      pretenders
#
#        ascents_count  repeat_sum  recommend_sum  tall_recommend_sum  \
# 55084              2         0.0            0.0                   0
# 55085              2         0.0            0.0                  -1
# 55086              2         0.0            1.0                   0
#
#        grade_mean  sentiment_mean  rating_mean  yellow_id_mean  \
# 55084        36.0             NaN          NaN             0.0
# 55085        39.5             0.0          2.0           255.0
# 55086        49.0             0.0          NaN           255.0
#
#        first_ascent_mean  cluster
# 55084                0.0        0
# 55085                0.0        1
# 55086                0.0        1

# %% [markdown]
# ## Prepare the dataframe

# %% [markdown]
# We will use the following values
# - rating_mean -> the mean value of the route rating
# - repeat_rate -> the sum of times that the route have been repeated by the same person divided by ascensions
# - recommend_rate -> times that the route has been recommended divided by ascensions
# - sentiment_rate -> sentiment count divided by comments count

# %%
routes_rate = routes.copy()
routes_rate['recommend_rate'] = routes_rate.recommend_sum / routes_rate.ascents_count

routes_rate = routes_rate[['rating_mean','recommend_rate','sentiment_mean']]
print(routes_rate.shape)
routes_rate.tail(3)
# Out:
# (55087, 3)
#        rating_mean  recommend_rate  sentiment_mean
# 55084          NaN             0.0             NaN
# 55085          2.0             0.0             0.0
# 55086          NaN             0.5             0.0

# %% [markdown]
# Replace nan by mean

# %%
routes_rate.isna().sum()
# Out:
# rating_mean        5812
# recommend_rate        0
# sentiment_mean    10492
# dtype: int64

# %%
routes_rate.rating_mean = routes_rate.rating_mean.fillna(np.mean(routes_rate.rating_mean))

# %%
routes_rate.rating_mean.hist()
# Out:
# <AxesSubplot:>

# %%
routes_rate.replace([np.inf, -np.inf], np.nan, inplace=True)
routes_rate.sentiment_mean = routes_rate.sentiment_mean.fillna(0)
routes_rate.sentiment_mean.hist()
# Out:
# <AxesSubplot:>

# %%
routes_rate.sentiment_mean.value_counts()
# Out:
#  0.000000    54241
#  0.458800       53
#  0.229400       36
#  0.152933       30
#  0.255300       23
#              ...
#  0.006822        1
#  0.005281        1
#  0.005153        1
# -0.154943        1
#  0.039060        1
# Name: sentiment_mean, Length: 283, dtype: int64

# %%
routes_rate.recommend_rate.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
#  #### Scale them

# %%
X = routes_rate.copy()
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
filename = "../transformer/scaler_rating.pickle" # Path with filename
with open(filename, "wb") as file:
        pickle.dump(scaler,file)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
print(X_scaled_df.shape)
display(X_scaled_df.head(3))
# Out:
# (55087, 3)
#    rating_mean  recommend_rate  sentiment_mean
# 0    -0.430209        0.611322        -0.07357
# 1    -0.887456        0.832217        -0.07357
# 2    -0.430209       -0.493151        -0.07357

# %% [markdown]
# ## Group the 3 features into one

# %% [markdown]
# ### Check the PCA

# %%
pca = PCA(n_components=None)
principalComponents = pca.fit_transform(X_scaled_df)
principalDf = pd.DataFrame(data = principalComponents)
pca.explained_variance_ratio_
# Out:
# array([0.4412073 , 0.33333369, 0.22545902])

# %% [markdown]
# We see that we cannot get only one feature from this, it should be higher than 80%

# %% [markdown]
# #### Check the distribution

# %%
# %matplotlib notebook
plot3D(x = X_scaled_df['rating_mean'],y = X_scaled_df['recommend_rate'],z = X_scaled_df['sentiment_mean'],color = X_scaled_df['rating_mean'], fraction = 0.2)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Mean

# %% [markdown]
# Just a simple mean gets the highest for a perfect rating in every feature, the lowest for the opposite

# %%
routes['rating_tot'] = (X_scaled_df.rating_mean + X_scaled_df.recommend_rate + X_scaled_df.sentiment_mean)/4

# %%
routes = routes.drop(columns = ['repeat_sum','rating_mean','ascents_count','sentiment_mean','recommend_sum','yellow_id_mean','first_ascent_mean'])
routes.head()
# Out:
#    name_id country        crag       sector                    name  \
# 0        0     and  montserrat  prohibitivo                el mehir
# 1        1     and  montserrat  prohibitivo  el pas de la discordia
# 2        2     and  montserrat  prohibitivo                    la x
# 3        3     and    tartareu   bombo suis           tenedor libre
# 4        4     arg  bandurrias       rincon              tendinitis
#
#    tall_recommend_sum  grade_mean  cluster  rating_tot
# 0                  -1   49.000000        0    0.026886
# 1                   0   49.000000        0   -0.032202
# 2                  -1   49.250000        0   -0.249232
# 3                   0   44.333333        0    0.760251
# 4                   1   48.500000        0   -0.706480

# %%
routes.to_csv('../data/routes_rated.csv')
